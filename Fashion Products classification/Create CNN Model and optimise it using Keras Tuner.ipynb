# %% [markdown]
# # Create CNN Model and optimise it using Keras Tuner

# %%
# !pip install keras-tuner
# Out:
# ...
# WARNING: Error parsing dependencies of pyodbc: Invalid version: '4.0.0-unsupported'
# WARNING: Error parsing dependencies of pyzmq: Invalid version: 'cpython'
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Nishant Moona\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#   File "C:\Users\Nishant Moona\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#   File "C:\Users\Nishant Moona\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Nishant Moona\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 483, in run
#     installed_versions[distribution.canonical_name] = distribution.version
#   File "C:\Users\Nishant Moona\anaconda3\lib\site-packages\pip\_internal\metadata\pkg_resources.py", line 192, in version
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
# Did in Google COlab
