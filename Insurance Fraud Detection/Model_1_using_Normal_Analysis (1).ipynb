# %% [markdown]
# ## Libraries required for running the code

# %%
# Importing the important libraries required for this machine learning technique
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Loading and Description of the Dataset

# %%
# Transfering data from the CSV file to a dataframe df
df = pd.read_csv("C:/Users/Nishant Moona/Downloads/Capstone Data.csv")

# %%
# General Information about the dataset
ir = df.shape[0]
ic = df.shape[1]
print("The total number of observations in the given dataset are: ", ir)
print("The total number of features/dimensions of the given dataset are: ", ic-1)
print("The target KPI is: ", "BMA_pol_auto")
# Out:
# The total number of observations in the given dataset are:  51546
# The total number of features/dimensions of the given dataset are:  195
# The target KPI is:  BMA_pol_auto

# %%
# The data types for each of the features/dimensions of the given dataset
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51546 entries, 0 to 51545
# Data columns (total 196 columns):
#  #    Column                           Dtype
# ---   ------                           -----
#  0    id17                             int64
#  1    id18                             int64
#  2    id21                             float64
#  3    id55                             float64
#  4    id58_1                           int64
#  5    id58_2                           int64
#  6    id58_3                           int64
#  7    id59                             float64
#  8    id60                             float64
#  9    id61                             float64
#  10   id70                             int64
#  11   ValorVehiculoMercado             float64
#  12   SINCOTotalVehiculos              float64
#  13   DGT_001                          float64
#  14   DGT_002                          float64
#  15   DGC_001                          float64
#  16   DGC_002                          float64
#  17   DGC_003                          float64
#  18   DGC_004                          float64
#  19   DGC_005                          float64
#  20   DGC_006                          float64
#  21   DGC_007                          float64
#  22   DGC_008                          float64
#  23   DGC_009                          float64
#  24   DGC_010                          float64
#  25   DGC_011                          float64
#  26   DGC_012                          float64
#  27   DGC_013                          float64
#  28   DGC_014                          float64
#  29   DGC_015                          float64
#  30   DGC_016                          float64
#  31   DGC_017                          float64
#  32   DGC_018                          float64
#  33   DGC_019                          float64
#  34   DGC_020                          float64
#  35   INE_001                          float64
#  36   INE_002                          float64
#  37   INE_003                          float64
#  38   INE_004                          float64
#  39   INE_005                          float64
#  40   INE_006                          float64
#  41   INE_007                          float64
#  42   INE_008                          float64
#  43   INE_009                          float64
#  44   INE_010                          float64
#  45   INE_011                          float64
#  46   INE_012                          float64
#  47   INE_013                          float64
#  48   INE_014                          float64
#  49   INE_015                          float64
#  50   INE_016                          float64
#  51   INE_017                          float64
#  52   INE_018                          float64
#  53   INE_019                          float64
#  54   INE_020                          float64
#  55   INE_021                          float64
#  56   INE_022                          float64
#  57   INE_023                          float64
#  58   INE_024                          float64
#  59   INE_025                          float64
#  60   INE_026                          float64
#  61   INE_027                          float64
#  62   INE_028                          float64
#  63   INE_029                          float64
#  64   INE_030                          float64
#  65   INE_031                          float64
#  66   INE_032                          float64
#  67   INE_033                          float64
#  68   INE_034                          float64
#  69   INE_035                          float64
#  70   INE_036                          float64
#  71   INE_037                          float64
#  72   INE_038                          float64
#  73   INE_039                          float64
#  74   INE_040                          float64
#  75   INE_041                          float64
#  76   INE_042                          float64
#  77   INE_043                          float64
#  78   INE_044                          float64
#  79   INE_045                          float64
#  80   INE_046                          float64
#  81   INE_047                          float64
#  82   INE_048                          float64
#  83   INE_049                          float64
#  84   INE_050                          float64
#  85   INE_051                          float64
#  86   INE_052                          float64
#  87   INE_053                          float64
#  88   INE_054                          float64
#  89   INE_055                          float64
#  90   INE_056                          float64
#  91   INE_057                          float64
#  92   SEA_001                          float64
#  93   SEA_002                          float64
#  94   SEA_003                          float64
#  95   SEA_004                          float64
#  96   SEA_005                          float64
#  97   SEA_006                          float64
#  98   SEA_007                          float64
#  99   SEA_008                          float64
#  100  SEA_009                          float64
#  101  SEA_010                          float64
#  102  OSM_001                          float64
#  103  IGN_001                          float64
#  104  REP_001                          float64
#  105  REP_002                          float64
#  106  REP_003                          float64
#  107  REP_004                          float64
#  108  REP_005                          float64
#  109  REP_006                          float64
#  110  REP_007                          float64
#  111  REP_008                          float64
#  112  REP_009                          float64
#  113  REP_010                          float64
#  114  ScoreAda                         int64
#  115  NacionalidadID                   int64
#  116  ProvinciaID                      int64
#  117  CiaAnteriorID                    int64
#  118  ComarcaID                        int64
#  119  TiempoSINCO                      int64
#  120  PerteneceSINCO                   float64
#  121  TotalMatriculasSINCO             int64
#  122  TiempoMedioSINCO                 float64
#  123  TiempoSeguroSINCO                float64
#  124  TiempoSINCO_Anos                 float64
#  125  FrecuenciaDanyosMateriales       float64
#  126  FrecuenciaDanyosPersonales       float64
#  127  FrecuenciaSiniestroSINCO         float64
#  128  NV_AutomovilSINCO                int64
#  129  NV_MotocicletaSINCO              int64
#  130  NV_OtrosSINCO                    int64
#  131  ScoreCanal                       float64
#  132  PrimaTotalPoliza                 float64
#  133  ComisionTotalPoliza              float64
#  134  SiniestralidadTotalPoliza        float64
#  135  ExposicionTotalPoliza            int64
#  136  Edad                             int64
#  137  Antiguedad_Carnet                int64
#  138  AnyoPoliza                       int64
#  139  AntiguedadVehiculo               int64
#  140  id24                             int64
#  141  id71                             int64
#  142  SINCOMatriculaIncluida           float64
#  143  ContrataLunas                    int64
#  144  ContrataAsistencia               int64
#  145  ContrataDanyosPropios            int64
#  146  Conductor2ID                     int64
#  147  NumeroDanyosMaterialesSINCO      int64
#  148  ProcesoDanyosMaterialesSINCO     int64
#  149  NumeroDanyosPersonalesSINCO      int64
#  150  ProcesoDanyosPersonalesSINCO     int64
#  151  id72_2                           int64
#  152  riesgo_0                         int64
#  153  riesgo_4                         int64
#  154  riesgo_3                         int64
#  155  riesgo_2                         int64
#  156  riesgo_1                         int64
#  157  id13_B                           int64
#  158  id13_C                           int64
#  159  id13_D                           int64
#  160  id13_E                           int64
#  161  id13_F                           int64
#  162  id13_G                           int64
#  163  id13_H                           int64
#  164  id13_I                           int64
#  165  id13_Z                           int64
#  166  id14_EXPANDE                     int64
#  167  id14_INICIA                      int64
#  168  id14_MANTENIMIENTO               int64
#  169  id14_OPTIMA                      int64
#  170  id14_OPTIMA_PLUS                 int64
#  171  id14_PROYECTA                    int64
#  172  id15_AGTES_VINCULADOS            int64
#  173  id15_CORREDORES                  int64
#  174  id15_EMPLEADOS                   int64
#  175  id15_OFIC_ENTIDAD                int64
#  176  id54_ANUAL_EFECTIVO              int64
#  177  id54_SEMESTRAL_DOMICILIADO       int64
#  178  id54_SEMESTRAL_EFECTIVO          int64
#  179  Subramo_CICLOMOTOR               int64
#  180  Subramo_COMERCI_MENOS_DE_3_5TN_  int64
#  181  Subramo_MOTOCICLETA              int64
#  182  Subramo_TURISMO_NO_CUADRICICLOS  int64
#  183  Subramo_VEHICULOS_AGRICOLAS      int64
#  184  Subramo_VEHICULOS_INDUSTRIALES   int64
#  185  TipoConsultaSINCO_Tomador        int64
#  186  NotaLUA_B                        int64
#  187  NotaLUA_C                        int64
#  188  NotaLUA_D                        int64
#  189  NotaLUA_E                        int64
#  190  NotaLUA_F                        int64
#  191  NotaLUA_G                        int64
#  192  SINCO                            int64
#  193  Cliente_Diverso                  int64
#  194  BMA_pol                          float64
#  195  BMA_pol_auto                     float64
# dtypes: float64(122), int64(74)
# memory usage: 77.1 MB

# %%
# Statistical description of each feature in the dataset
df.describe()
# Out:
#                id17          id18          id21          id55        id58_1  \
# count  51546.000000  51546.000000  51546.000000  51546.000000  51546.000000
# mean     296.033892    179.140942  21381.973629    -46.621367      0.193497
# std      258.479784    208.867095  17459.321966     10.232688      0.538048
# min       20.000000      0.000000   1008.000000    -52.500000      0.000000
# 25%       36.000000     41.000000   3690.000000    -50.000000      0.000000
# 50%      200.000000    107.000000  17442.500000    -50.000000      0.000000
# 75%      461.000000    201.000000  41350.000000    -47.500000      0.000000
# max      900.000000    999.000000  52006.000000    250.000000     53.000000
#
#              id58_2        id58_3           id59          id60           id61  \
# count  51546.000000  51546.000000   51546.000000  51546.000000   51546.000000
# mean       0.419664      0.073042     904.412240    138.315077     520.706975
# std        0.880897      0.557700    4845.141251    721.748287    5538.067504
# min        0.000000      0.000000     -19.860000    -60.910000   -3282.730000
# 25%        0.000000      0.000000       0.000000      0.000000       0.000000
# 50%        0.000000      0.000000       0.000000      0.000000       0.000000
# 75%        1.000000      0.000000       0.000000      0.000000       0.000000
# max       53.000000    105.000000  415182.410000  53166.370000  706072.550000
#
#        ...     NotaLUA_B     NotaLUA_C     NotaLUA_D     NotaLUA_E  \
# count  ...  51546.000000  51546.000000  51546.000000  51546.000000
# mean   ...      0.038490      0.104722      0.159566      0.291313
# std    ...      0.192378      0.306198      0.366207      0.454372
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      1.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#           NotaLUA_F     NotaLUA_G    SINCO  Cliente_Diverso        BMA_pol  \
# count  51546.000000  51546.000000  51546.0     51546.000000   51546.000000
# mean       0.203255      0.167811      1.0         0.642028      48.019878
# std        0.402425      0.373702      0.0         0.479408    2288.083131
# min        0.000000      0.000000      1.0         0.000000 -185990.403800
# 25%        0.000000      0.000000      1.0         0.000000      81.573318
# 50%        0.000000      0.000000      1.0         1.000000     182.049500
# 75%        0.000000      0.000000      1.0         1.000000     267.787780
# max        1.000000      1.000000      1.0         1.000000   28207.913410
#
#         BMA_pol_auto
# count   51546.000000
# mean       45.242747
# std      2479.687340
# min   -185990.403800
# 25%        75.253375
# 50%       181.123669
# 75%       272.209048
# max     28207.913410
#
# [8 rows x 196 columns]

# %% [markdown]
# ## Data Pre-processing

# %%
# Remove insignificant feature columns from the dataset whose data is unavailable
df = df.drop(['BMA_pol','PrimaTotalPoliza', 'ComisionTotalPoliza', 'SiniestralidadTotalPoliza', 'ExposicionTotalPoliza'], axis=1)

# %%
# find the number of null values in the dataset

pd.set_option('display.max_rows', None)
print(df.isna().sum())

# find the features where null values exist

null_cols = [columns for columns in df.columns if df[columns].isna().sum() != 0]
if len(null_cols) == 0:
    print("There are no null columns in the dataset")
else:
    print(f'There are {len(null_cols)} in the dataset')
    print("The features having null values are as below:- ")
    print(",".join(null_cols))
    
# Removal of null columns
if len(null_cols) != 0:
    df = df.dropna(axis = 1)
# Out:
# id17                               0
# id18                               0
# id21                               0
# id55                               0
# id58_1                             0
# id58_2                             0
# id58_3                             0
# id59                               0
# id60                               0
# id61                               0
# id70                               0
# ValorVehiculoMercado               0
# SINCOTotalVehiculos                0
# DGT_001                            0
# DGT_002                            0
# DGC_001                            0
# DGC_002                            0
# DGC_003                            0
# DGC_004                            0
# DGC_005                            0
# DGC_006                            0
# DGC_007                            0
# DGC_008                            0
# DGC_009                            0
# DGC_010                            0
# DGC_011                            0
# DGC_012                            0
# DGC_013                            0
# DGC_014                            0
# DGC_015                            0
# DGC_016                            0
# DGC_017                            0
# DGC_018                            0
# DGC_019                            0
# DGC_020                            0
# INE_001                            0
# INE_002                            0
# INE_003                            0
# INE_004                            0
# INE_005                            0
# INE_006                            0
# INE_007                            0
# INE_008                            0
# INE_009                            0
# INE_010                            0
# INE_011                            0
# INE_012                            0
# INE_013                            0
# INE_014                            0
# INE_015                            0
# INE_016                            0
# INE_017                            0
# INE_018                            0
# INE_019                            0
# INE_020                            0
# INE_021                            0
# INE_022                            0
# INE_023                            0
# INE_024                            0
# INE_025                            0
# INE_026                            0
# INE_027                            0
# INE_028                            0
# INE_029                            0
# INE_030                            0
# INE_031                            0
# INE_032                            0
# INE_033                            0
# INE_034                            0
# INE_035                            0
# INE_036                            0
# INE_037                            0
# INE_038                            0
# INE_039                            0
# INE_040                            0
# INE_041                            0
# INE_042                            0
# INE_043                            0
# INE_044                            0
# INE_045                            0
# INE_046                            0
# INE_047                            0
# INE_048                            0
# INE_049                            0
# INE_050                            0
# INE_051                            0
# INE_052                            0
# INE_053                            0
# INE_054                            0
# INE_055                            0
# INE_056                            0
# INE_057                            0
# SEA_001                            0
# SEA_002                            0
# SEA_003                            0
# SEA_004                            0
# SEA_005                            0
# SEA_006                            0
# SEA_007                            0
# SEA_008                            0
# SEA_009                            0
# SEA_010                            0
# OSM_001                            0
# IGN_001                            0
# REP_001                            0
# REP_002                            0
# REP_003                            0
# REP_004                            0
# REP_005                            0
# REP_006                            0
# REP_007                            0
# REP_008                            0
# REP_009                            0
# REP_010                            0
# ScoreAda                           0
# NacionalidadID                     0
# ProvinciaID                        0
# CiaAnteriorID                      0
# ComarcaID                          0
# TiempoSINCO                        0
# PerteneceSINCO                     0
# TotalMatriculasSINCO               0
# TiempoMedioSINCO                   0
# TiempoSeguroSINCO                  0
# TiempoSINCO_Anos                   0
# FrecuenciaDanyosMateriales         0
# FrecuenciaDanyosPersonales         0
# FrecuenciaSiniestroSINCO           0
# NV_AutomovilSINCO                  0
# NV_MotocicletaSINCO                0
# NV_OtrosSINCO                      0
# ScoreCanal                         0
# Edad                               0
# Antiguedad_Carnet                  0
# AnyoPoliza                         0
# AntiguedadVehiculo                 0
# id24                               0
# id71                               0
# SINCOMatriculaIncluida             0
# ContrataLunas                      0
# ContrataAsistencia                 0
# ContrataDanyosPropios              0
# Conductor2ID                       0
# NumeroDanyosMaterialesSINCO        0
# ProcesoDanyosMaterialesSINCO       0
# NumeroDanyosPersonalesSINCO        0
# ProcesoDanyosPersonalesSINCO       0
# id72_2                             0
# riesgo_0                           0
# riesgo_4                           0
# riesgo_3                           0
# riesgo_2                           0
# riesgo_1                           0
# id13_B                             0
# id13_C                             0
# id13_D                             0
# id13_E                             0
# id13_F                             0
# id13_G                             0
# id13_H                             0
# id13_I                             0
# id13_Z                             0
# id14_EXPANDE                       0
# id14_INICIA                        0
# id14_MANTENIMIENTO                 0
# id14_OPTIMA                        0
# id14_OPTIMA_PLUS                   0
# id14_PROYECTA                      0
# id15_AGTES_VINCULADOS              0
# id15_CORREDORES                    0
# id15_EMPLEADOS                     0
# id15_OFIC_ENTIDAD                  0
# id54_ANUAL_EFECTIVO                0
# id54_SEMESTRAL_DOMICILIADO         0
# id54_SEMESTRAL_EFECTIVO            0
# Subramo_CICLOMOTOR                 0
# Subramo_COMERCI_MENOS_DE_3_5TN_    0
# Subramo_MOTOCICLETA                0
# Subramo_TURISMO_NO_CUADRICICLOS    0
# Subramo_VEHICULOS_AGRICOLAS        0
# Subramo_VEHICULOS_INDUSTRIALES     0
# TipoConsultaSINCO_Tomador          0
# NotaLUA_B                          0
# NotaLUA_C                          0
# NotaLUA_D                          0
# NotaLUA_E                          0
# NotaLUA_F                          0
# NotaLUA_G                          0
# SINCO                              0
# Cliente_Diverso                    0
# BMA_pol_auto                       0
# dtype: int64
# There are no null columns in the dataset

# %%
# Checking for duplicated values

if df[df.duplicated()].shape[0] == 0:
    print("There are no duplicated rows in the dataset")
else:
    print("The number of duplicated rows in the dataset are",df[df.duplicated()].shape[0])

# Removal of duplicated values from the dataset

if df[df.duplicated()].shape[0] != 0:
    df.drop_duplicates()
# Out:
# There are no duplicated rows in the dataset

# %%
# Converting the target KPI (BMA_pol_auto) into a categorical variable for Classification
df['Profitability'] = [0 if df.loc[i,'BMA_pol_auto'] > 0 else 1 for i in range(df.shape[0])]

# %%
# Splitting the dataset into Independent Feature Variables and Target Variable

y = df['Profitability']
X = df.drop(['Profitability'], axis = 1)

# Splitting the dataset into Training & Validation and Test datasets
X_train_val,X_test,y_train_val,y_test = train_test_split(X,y,test_size = 0.20, random_state = 123)

# Splitting the Training and Validation dataset into Training and Validation datasets
X_train, X_val, y_train, y_val = train_test_split(X_train_val,y_train_val, test_size = 0.25, random_state = 123)

# Dropping the target variable "BMA_Pol_auto" from the training and validation dataset
X_train = X_train.drop(['BMA_pol_auto'], axis = 1)
X_val = X_val.drop(['BMA_pol_auto'], axis = 1)

# Printing a summary of the training, testing and validation dataset

print(f"The total number of observations of the training dataset is {X_train.shape[0]}")
print(f"The total number of observations of the validation dataset is {X_val.shape[0]}")
print(f"The total number of observations of the testing dataset is {X_test.shape[0]}")
# Out:
# The total number of observations of the training dataset is 30927
# The total number of observations of the validation dataset is 10309
# The total number of observations of the testing dataset is 10310

# %% [markdown]
# The training dataset will be used for training the learning algorithm. The validation dataset will be used for finding the optimal number of features based on feature importance using the trained algorithm. The test set will be used for determining the accuracy of the models used

# %% [markdown]
# ## XGBoost Classifier Algorithm

# %%
# Fitting the XGBoost Algorithm on the training dataset

xgb = XGBClassifier()
xgb.fit(X_train,y_train)

# Predicting the target variable using the trained model

y_pred = xgb.predict(X_val)

# Classification Report

print("The Classification report for XGBoost Classifier", end = "\n\n")
print(classification_report(y_val, y_pred))

# Importance of each attribute/features

xgb_results = pd.DataFrame(X_train.columns)
xgb_results.rename(columns = {0:"Feature Names"}, inplace = True)
xgb_results['Feature Importance'] = xgb.feature_importances_
print("----------------------------------------------------")
print("The List of Features and their respective importance", end = "\n")
xgb_results
# Out:
# The Classification report for XGBoost Classifier
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      8372
#            1       0.58      0.22      0.32      1937
#
#     accuracy                           0.82     10309
#    macro avg       0.71      0.59      0.61     10309
# weighted avg       0.79      0.82      0.79     10309
#
# ----------------------------------------------------
# The List of Features and their respective importance
#                        Feature Names  Feature Importance
# 0                               id17            0.003899
# 1                               id18            0.004178
# 2                               id21            0.006437
# 3                               id55            0.035281
# 4                             id58_1            0.004354
# 5                             id58_2            0.005569
# 6                             id58_3            0.004819
# 7                               id59            0.004690
# 8                               id60            0.005608
# 9                               id61            0.004577
# 10                              id70            0.004602
# 11              ValorVehiculoMercado            0.005418
# 12               SINCOTotalVehiculos            0.005191
# 13                           DGT_001            0.005362
# 14                           DGT_002            0.004837
# 15                           DGC_001            0.005145
# 16                           DGC_002            0.004936
# 17                           DGC_003            0.004932
# 18                           DGC_004            0.003901
# 19                           DGC_005            0.004733
# 20                           DGC_006            0.006077
# 21                           DGC_007            0.005568
# 22                           DGC_008            0.005019
# 23                           DGC_009            0.004056
# 24                           DGC_010            0.004671
# 25                           DGC_011            0.005548
# 26                           DGC_012            0.004620
# 27                           DGC_013            0.005030
# 28                           DGC_014            0.005022
# 29                           DGC_015            0.005197
# 30                           DGC_016            0.004344
# 31                           DGC_017            0.004495
# 32                           DGC_018            0.005158
# 33                           DGC_019            0.005297
# 34                           DGC_020            0.004665
# 35                           INE_001            0.005553
# 36                           INE_002            0.004955
# 37                           INE_003            0.004993
# 38                           INE_004            0.005487
# 39                           INE_005            0.005410
# 40                           INE_006            0.005751
# 41                           INE_007            0.004266
# 42                           INE_008            0.004332
# 43                           INE_009            0.005276
# 44                           INE_010            0.005550
# 45                           INE_011            0.005018
# 46                           INE_012            0.004441
# 47                           INE_013            0.004774
# 48                           INE_014            0.004366
# 49                           INE_015            0.006780
# 50                           INE_016            0.004571
# 51                           INE_017            0.005025
# 52                           INE_018            0.005058
# 53                           INE_019            0.004115
# 54                           INE_020            0.005865
# 55                           INE_021            0.006879
# 56                           INE_022            0.005203
# 57                           INE_023            0.005442
# 58                           INE_024            0.003741
# 59                           INE_025            0.005926
# 60                           INE_026            0.005006
# 61                           INE_027            0.005125
# 62                           INE_028            0.004536
# 63                           INE_029            0.003866
# 64                           INE_030            0.005145
# 65                           INE_031            0.005358
# 66                           INE_032            0.004960
# 67                           INE_033            0.004326
# 68                           INE_034            0.005938
# 69                           INE_035            0.004624
# 70                           INE_036            0.005573
# 71                           INE_037            0.003817
# 72                           INE_038            0.005668
# 73                           INE_039            0.004480
# 74                           INE_040            0.005145
# 75                           INE_041            0.005602
# 76                           INE_042            0.005313
# 77                           INE_043            0.005465
# 78                           INE_044            0.005066
# 79                           INE_045            0.005199
# 80                           INE_046            0.004996
# 81                           INE_047            0.006070
# 82                           INE_048            0.006430
# 83                           INE_049            0.004117
# 84                           INE_050            0.005201
# 85                           INE_051            0.004331
# 86                           INE_052            0.000000
# 87                           INE_053            0.005450
# 88                           INE_054            0.004491
# 89                           INE_055            0.004293
# 90                           INE_056            0.005514
# 91                           INE_057            0.005013
# 92                           SEA_001            0.006002
# 93                           SEA_002            0.005146
# 94                           SEA_003            0.005578
# 95                           SEA_004            0.003946
# 96                           SEA_005            0.004739
# 97                           SEA_006            0.003780
# 98                           SEA_007            0.004520
# 99                           SEA_008            0.005021
# 100                          SEA_009            0.004701
# 101                          SEA_010            0.005970
# 102                          OSM_001            0.004949
# 103                          IGN_001            0.003452
# 104                          REP_001            0.004155
# 105                          REP_002            0.004480
# 106                          REP_003            0.005908
# 107                          REP_004            0.005491
# 108                          REP_005            0.004848
# 109                          REP_006            0.004811
# 110                          REP_007            0.003587
# 111                          REP_008            0.005629
# 112                          REP_009            0.003746
# 113                          REP_010            0.005676
# 114                         ScoreAda            0.004937
# 115                   NacionalidadID            0.003819
# 116                      ProvinciaID            0.003487
# 117                    CiaAnteriorID            0.004009
# 118                        ComarcaID            0.007738
# 119                      TiempoSINCO            0.003961
# 120                   PerteneceSINCO            0.011670
# 121             TotalMatriculasSINCO            0.005905
# 122                 TiempoMedioSINCO            0.005099
# 123                TiempoSeguroSINCO            0.004870
# 124                 TiempoSINCO_Anos            0.000000
# 125       FrecuenciaDanyosMateriales            0.004608
# 126       FrecuenciaDanyosPersonales            0.004151
# 127         FrecuenciaSiniestroSINCO            0.022231
# 128                NV_AutomovilSINCO            0.004646
# 129              NV_MotocicletaSINCO            0.003874
# 130                    NV_OtrosSINCO            0.005841
# 131                       ScoreCanal            0.005264
# 132                             Edad            0.004331
# 133                Antiguedad_Carnet            0.004094
# 134                       AnyoPoliza            0.015135
# 135               AntiguedadVehiculo            0.003862
# 136                             id24            0.000000
# 137                             id71            0.006273
# 138           SINCOMatriculaIncluida            0.007666
# 139                    ContrataLunas            0.012753
# 140               ContrataAsistencia            0.004918
# 141            ContrataDanyosPropios            0.004012
# 142                     Conductor2ID            0.004869
# 143      NumeroDanyosMaterialesSINCO            0.011937
# 144     ProcesoDanyosMaterialesSINCO            0.003512
# 145      NumeroDanyosPersonalesSINCO            0.009464
# 146     ProcesoDanyosPersonalesSINCO            0.007756
# 147                           id72_2            0.007718
# 148                         riesgo_0            0.004860
# 149                         riesgo_4            0.003660
# 150                         riesgo_3            0.005736
# 151                         riesgo_2            0.004668
# 152                         riesgo_1            0.004224
# 153                           id13_B            0.005000
# 154                           id13_C            0.004295
# 155                           id13_D            0.003820
# 156                           id13_E            0.002919
# 157                           id13_F            0.004356
# 158                           id13_G            0.003951
# 159                           id13_H            0.011697
# 160                           id13_I            0.003357
# 161                           id13_Z            0.003205
# 162                     id14_EXPANDE            0.004010
# 163                      id14_INICIA            0.004708
# 164               id14_MANTENIMIENTO            0.010722
# 165                      id14_OPTIMA            0.003100
# 166                 id14_OPTIMA_PLUS            0.000000
# 167                    id14_PROYECTA            0.002489
# 168            id15_AGTES_VINCULADOS            0.003788
# 169                  id15_CORREDORES            0.005763
# 170                   id15_EMPLEADOS            0.002015
# 171                id15_OFIC_ENTIDAD            0.005730
# 172              id54_ANUAL_EFECTIVO            0.005500
# 173       id54_SEMESTRAL_DOMICILIADO            0.003940
# 174          id54_SEMESTRAL_EFECTIVO            0.003301
# 175               Subramo_CICLOMOTOR            0.000000
# 176  Subramo_COMERCI_MENOS_DE_3_5TN_            0.005744
# 177              Subramo_MOTOCICLETA            0.004561
# 178  Subramo_TURISMO_NO_CUADRICICLOS            0.003351
# 179      Subramo_VEHICULOS_AGRICOLAS            0.000000
# 180   Subramo_VEHICULOS_INDUSTRIALES            0.000000
# 181        TipoConsultaSINCO_Tomador            0.006928
# 182                        NotaLUA_B            0.004377
# 183                        NotaLUA_C            0.003186
# 184                        NotaLUA_D            0.003538
# 185                        NotaLUA_E            0.004371
# 186                        NotaLUA_F            0.005203
# 187                        NotaLUA_G            0.006634
# 188                            SINCO            0.000000
# 189                  Cliente_Diverso            0.022622

# %%
# Listing the Feature importances and metric scores used for validating the ML model
d = xgb.feature_importances_
r = list(X.columns)
max_imp = max(d)
min_imp = min(d)
val = list(np.linspace(max_imp, min_imp, 50))
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
overall_accuracy_scores = []
list_of_predictors = []
No_of_predictors = []
for value in val:
    u = []
    columns = [u.append(r[i]) for i in range(len(d)) if d[i] >= value]
    # print(u)
    list_of_predictors.append(u)
    No_of_predictors.append(len(u))
    X_training = X_train[u]
    X_value = X_val[u]
    # print(X.columns)
    
    # X_train, X_val, y_train, y_val = train_test_split(X_train_val,y_train_val, test_size = 0.25)
    xgb = XGBClassifier()
    xgb.fit(X_training,y_train)
    y_pred = xgb.predict(X_value)
    recall = recall_score(y_val,y_pred)
    precision = precision_score(y_val,y_pred)
    Overall_Accuracy = accuracy_score(y_val, y_pred)
    roc_auc = roc_auc_score(y_val,y_pred)
    f1 = f1_score(y_val,y_pred)
    recall_scores.append(recall)
    precision_scores.append(precision)
    roc_auc_scores.append(roc_auc)
    overall_accuracy_scores.append(Overall_Accuracy)
    f1_scores.append(f1)

# %%
# Plotting the values against
metrics = [precision_scores,recall_scores,roc_auc_scores,f1_scores,overall_accuracy_scores]
metrics_name = ['precision_scores','recall_scores','roc_auc_scores','f1_scores','overall_accuracy_scores']
for k in range(len(metrics)):
    x_val = [str(i) for i in No_of_predictors]
    y_value = metrics[k].copy()
    plt.figure(figsize = (12,5))
    sns.lineplot(x = x_val, y = y_value)
    plt.xlabel("No. of Predictors")
    plt.ylabel(metrics_name[k])
    plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x = roc_auc_scores.index(max(roc_auc_scores))
xgbc = ", ".join(list_of_predictors[x])
xgbc_score_library = {"ROC AUC Score":round(roc_auc_scores[x],2),"Recall Score":round(recall_scores[x],2),'Precision Score':round(precision_scores[x],2), 'F1 Score':round(f1_scores[x],2), "Overall Accuracy":round(overall_accuracy_scores[x],2),'Optimum predictors':No_of_predictors[x], 'list_of_predictors':xgbc}
list_of_models = []
list_of_models.append('XGBoost')
print(xgbc_score_library)
# Out:
# {'ROC AUC Score': 0.6, 'Recall Score': 0.24, 'Precision Score': 0.63, 'F1 Score': 0.35, 'Overall Accuracy': 0.83, 'Optimum predictors': 9, 'list_of_predictors': 'id55, PerteneceSINCO, FrecuenciaSiniestroSINCO, AnyoPoliza, ContrataLunas, NumeroDanyosMaterialesSINCO, id13_H, id14_MANTENIMIENTO, Cliente_Diverso'}

# %%
combined_model_library = []
combined_model_library.append(xgbc_score_library)

# %% [markdown]
# ## LGBM Classifier

# %%
# Fitting the LGBM Classifier Algorithm on the training dataset

lgb = LGBMClassifier()
lgb.fit(X_train,y_train)

# Predicting the target variable using the trained model

y_pred = lgb.predict(X_val)

# Classification Report

print("The Classification report for LGBM Classifier", end = "\n\n")
print(classification_report(y_val, y_pred))

# Importance of each attribute/features

lgb_results = pd.DataFrame(X_train.columns)
lgb_results.rename(columns = {0:"Feature Names"}, inplace = True)
lgb_results['Feature Importance'] = lgb.feature_importances_
print("----------------------------------------------------")
print("The List of Features and their respective importance", end = "\n")
lgb_results
# Out:
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019950 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 31076
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 187
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# The Classification report for LGBM Classifier
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      8372
#            1       0.67      0.19      0.30      1937
#
#     accuracy                           0.83     10309
#    macro avg       0.76      0.59      0.60     10309
# weighted avg       0.81      0.83      0.79     10309
#
# ----------------------------------------------------
# The List of Features and their respective importance
#                        Feature Names  Feature Importance
# 0                               id17                  10
# 1                               id18                  45
# 2                               id21                  14
# 3                               id55                 127
# 4                             id58_1                  10
# 5                             id58_2                  19
# 6                             id58_3                   3
# 7                               id59                  16
# 8                               id60                  10
# 9                               id61                  16
# 10                              id70                  51
# 11              ValorVehiculoMercado                  80
# 12               SINCOTotalVehiculos                  45
# 13                           DGT_001                  24
# 14                           DGT_002                  24
# 15                           DGC_001                  21
# 16                           DGC_002                  19
# 17                           DGC_003                   9
# 18                           DGC_004                   4
# 19                           DGC_005                   9
# 20                           DGC_006                  14
# 21                           DGC_007                  26
# 22                           DGC_008                  35
# 23                           DGC_009                  10
# 24                           DGC_010                  17
# 25                           DGC_011                  13
# 26                           DGC_012                  29
# 27                           DGC_013                  10
# 28                           DGC_014                  25
# 29                           DGC_015                  21
# 30                           DGC_016                  14
# 31                           DGC_017                  16
# 32                           DGC_018                  16
# 33                           DGC_019                  20
# 34                           DGC_020                   9
# 35                           INE_001                  29
# 36                           INE_002                  11
# 37                           INE_003                   7
# 38                           INE_004                  12
# 39                           INE_005                  14
# 40                           INE_006                  15
# 41                           INE_007                  11
# 42                           INE_008                   9
# 43                           INE_009                  16
# 44                           INE_010                  16
# 45                           INE_011                  19
# 46                           INE_012                  12
# 47                           INE_013                   7
# 48                           INE_014                   3
# 49                           INE_015                   9
# 50                           INE_016                  30
# 51                           INE_017                   8
# 52                           INE_018                  33
# 53                           INE_019                  13
# 54                           INE_020                  17
# 55                           INE_021                  12
# 56                           INE_022                   9
# 57                           INE_023                  10
# 58                           INE_024                   8
# 59                           INE_025                   5
# 60                           INE_026                   8
# 61                           INE_027                  22
# 62                           INE_028                   2
# 63                           INE_029                   5
# 64                           INE_030                   6
# 65                           INE_031                   3
# 66                           INE_032                  15
# 67                           INE_033                   6
# 68                           INE_034                  19
# 69                           INE_035                   7
# 70                           INE_036                   9
# 71                           INE_037                  11
# 72                           INE_038                   5
# 73                           INE_039                  10
# 74                           INE_040                  16
# 75                           INE_041                   8
# 76                           INE_042                  15
# 77                           INE_043                  16
# 78                           INE_044                  12
# 79                           INE_045                  14
# 80                           INE_046                  16
# 81                           INE_047                   3
# 82                           INE_048                  13
# 83                           INE_049                  11
# 84                           INE_050                   9
# 85                           INE_051                  12
# 86                           INE_052                   0
# 87                           INE_053                  12
# 88                           INE_054                   5
# 89                           INE_055                   9
# 90                           INE_056                  14
# 91                           INE_057                  12
# 92                           SEA_001                  12
# 93                           SEA_002                  21
# 94                           SEA_003                  33
# 95                           SEA_004                  15
# 96                           SEA_005                  25
# 97                           SEA_006                  23
# 98                           SEA_007                  14
# 99                           SEA_008                  21
# 100                          SEA_009                  24
# 101                          SEA_010                  18
# 102                          OSM_001                  21
# 103                          IGN_001                  14
# 104                          REP_001                  18
# 105                          REP_002                   7
# 106                          REP_003                   4
# 107                          REP_004                  13
# 108                          REP_005                  26
# 109                          REP_006                  14
# 110                          REP_007                  15
# 111                          REP_008                  31
# 112                          REP_009                  12
# 113                          REP_010                  28
# 114                         ScoreAda                  25
# 115                   NacionalidadID                  15
# 116                      ProvinciaID                   1
# 117                    CiaAnteriorID                  41
# 118                        ComarcaID                   3
# 119                      TiempoSINCO                  53
# 120                   PerteneceSINCO                  49
# 121             TotalMatriculasSINCO                  26
# 122                 TiempoMedioSINCO                  96
# 123                TiempoSeguroSINCO                  47
# 124                 TiempoSINCO_Anos                   0
# 125       FrecuenciaDanyosMateriales                  27
# 126       FrecuenciaDanyosPersonales                  16
# 127         FrecuenciaSiniestroSINCO                  57
# 128                NV_AutomovilSINCO                  21
# 129              NV_MotocicletaSINCO                   8
# 130                    NV_OtrosSINCO                   7
# 131                       ScoreCanal                  47
# 132                             Edad                  55
# 133                Antiguedad_Carnet                  46
# 134                       AnyoPoliza                 135
# 135               AntiguedadVehiculo                  69
# 136                             id24                   1
# 137                             id71                  15
# 138           SINCOMatriculaIncluida                  34
# 139                    ContrataLunas                   5
# 140               ContrataAsistencia                   9
# 141            ContrataDanyosPropios                   4
# 142                     Conductor2ID                   1
# 143      NumeroDanyosMaterialesSINCO                  14
# 144     ProcesoDanyosMaterialesSINCO                   0
# 145      NumeroDanyosPersonalesSINCO                   0
# 146     ProcesoDanyosPersonalesSINCO                   0
# 147                           id72_2                  17
# 148                         riesgo_0                   9
# 149                         riesgo_4                   5
# 150                         riesgo_3                   2
# 151                         riesgo_2                   5
# 152                         riesgo_1                   2
# 153                           id13_B                   8
# 154                           id13_C                   8
# 155                           id13_D                   2
# 156                           id13_E                   5
# 157                           id13_F                   3
# 158                           id13_G                   4
# 159                           id13_H                  20
# 160                           id13_I                   3
# 161                           id13_Z                   0
# 162                     id14_EXPANDE                   1
# 163                      id14_INICIA                   2
# 164               id14_MANTENIMIENTO                   1
# 165                      id14_OPTIMA                   0
# 166                 id14_OPTIMA_PLUS                   0
# 167                    id14_PROYECTA                   3
# 168            id15_AGTES_VINCULADOS                   0
# 169                  id15_CORREDORES                   3
# 170                   id15_EMPLEADOS                   0
# 171                id15_OFIC_ENTIDAD                   0
# 172              id54_ANUAL_EFECTIVO                   8
# 173       id54_SEMESTRAL_DOMICILIADO                   8
# 174          id54_SEMESTRAL_EFECTIVO                   0
# 175               Subramo_CICLOMOTOR                   1
# 176  Subramo_COMERCI_MENOS_DE_3_5TN_                   7
# 177              Subramo_MOTOCICLETA                   2
# 178  Subramo_TURISMO_NO_CUADRICICLOS                   2
# 179      Subramo_VEHICULOS_AGRICOLAS                   0
# 180   Subramo_VEHICULOS_INDUSTRIALES                   0
# 181        TipoConsultaSINCO_Tomador                   4
# 182                        NotaLUA_B                   1
# 183                        NotaLUA_C                   1
# 184                        NotaLUA_D                   2
# 185                        NotaLUA_E                   1
# 186                        NotaLUA_F                   2
# 187                        NotaLUA_G                   0
# 188                            SINCO                   0
# 189                  Cliente_Diverso                  31

# %%
d = lgb.feature_importances_
r = list(X.columns)
max_imp = max(d)
min_imp = min(d)
val = list(np.linspace(max_imp, min_imp, 50))
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
overall_accuracy_scores = []
list_of_predictors = []
No_of_predictors = []
for value in val:
    u = []
    columns = [u.append(r[i]) for i in range(len(d)) if d[i] >= value]
    # 
    list_of_predictors.append(u)
    No_of_predictors.append(len(u))
    X_training = X_train[u]
    X_value = X_val[u]
    # 
    
    lgb = LGBMClassifier()
    lgb.fit(X_training,y_train)
    y_pred = lgb.predict(X_value)
    recall = recall_score(y_val,y_pred)
    precision = precision_score(y_val,y_pred)
    roc_auc = roc_auc_score(y_val,y_pred)
    Overall_Accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val,y_pred)
    recall_scores.append(recall)
    precision_scores.append(precision)
    roc_auc_scores.append(roc_auc)
    overall_accuracy_scores.append(Overall_Accuracy)
    f1_scores.append(f1)
# Out:
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000215 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 1
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 1
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000185 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 1
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002749 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000193 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001348 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000188 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000177 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000929 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000151 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000165 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000873 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000164 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 35
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 290
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000165 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 290
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000186 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 290
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000194 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 290
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000191 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 290
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000578 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 545
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 4
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000184 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 545
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 4
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000176 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 545
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 4
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000196 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 545
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 4
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 593
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000245 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 593
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000231 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 593
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000354 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 593
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 593
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.100426 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 848
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 6
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001168 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1178
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001154 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1376
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001314 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2140
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001353 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2657
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001257 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2657
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001329 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2702
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001345 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2702
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002168 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3211
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024444 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3977
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003644 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4994
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004329 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6551
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 33
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004106 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 7571
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 37
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 9385
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006293 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11183
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 55
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009566 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17365
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 82
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20666
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 95
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013119 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25275
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016653 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 27849
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 134
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017816 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30216
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 156
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069
# [LightGBM] [Info] Number of positive: 5962, number of negative: 24965
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019834 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 31076
# [LightGBM] [Info] Number of data points in the train set: 30927, number of used features: 187
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.192777 -> initscore=-1.432069
# [LightGBM] [Info] Start training from score -1.432069

# %%
# Plotting the values against
metrics = [precision_scores,recall_scores,roc_auc_scores,f1_scores,overall_accuracy_scores]
metrics_name = ['precision_scores','recall_scores','roc_auc_scores','f1_scores','overall_accuracy_scores']
for k in range(len(metrics)):
    x_val = [str(i) for i in No_of_predictors]
    y_value = metrics[k].copy()
    plt.figure(figsize = (12,5))
    sns.lineplot(x = x_val, y = y_value)
    plt.xlabel("No. of Predictors")
    plt.ylabel(metrics_name[k])
    plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x = roc_auc_scores.index(max(roc_auc_scores))
lgbc = ", ".join(list_of_predictors[x])
lgbc_score_library = {"ROC AUC Score":round(roc_auc_scores[x],2),"Recall Score":round(recall_scores[x],2),'Precision Score':round(precision_scores[x],2), 'F1 Score':round(f1_scores[x],2), "Overall Accuracy":round(overall_accuracy_scores[x],2),'Optimum predictors':No_of_predictors[x], 'list_of_predictors':lgbc}
list_of_models.append('Light Gradient Boost')
print(lgbc_score_library)
# Out:
# {'ROC AUC Score': 0.59, 'Recall Score': 0.21, 'Precision Score': 0.66, 'F1 Score': 0.32, 'Overall Accuracy': 0.83, 'Optimum predictors': 12, 'list_of_predictors': 'id55, id70, ValorVehiculoMercado, TiempoSINCO, PerteneceSINCO, TiempoMedioSINCO, TiempoSeguroSINCO, FrecuenciaSiniestroSINCO, ScoreCanal, Edad, AnyoPoliza, AntiguedadVehiculo'}

# %%
combined_model_library.append(lgbc_score_library)

# %%
# Import necessary libraries
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, recall_score, precision_score, roc_auc_score, accuracy_score, f1_score
from sklearn.feature_selection import RFE
import numpy as np
import pandas as pd

# Fitting the MLP Classifier Algorithm on the training dataset
mlp = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=0)
mlp.fit(X_train, y_train)

# Predicting the target variable using the trained model
y_pred = mlp.predict(X_val)

# Classification Report
print("The Classification report for MLP Classifier", end = "\n\n")
print(classification_report(y_val, y_pred))

# Feature Importance using Recursive Feature Elimination (RFE)
# Logistic Regression is used here to rank features, as MLP doesn't have direct feature importance
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=1000)
rfe = RFE(estimator=log_reg, n_features_to_select=1)
rfe.fit(X_train, y_train)

# Importance of each attribute/features
rfe_ranking = rfe.ranking_
mlp_results = pd.DataFrame(X_train.columns)
mlp_results.rename(columns={0: "Feature Names"}, inplace=True)
mlp_results['Feature Importance (Rank)'] = rfe_ranking
print("----------------------------------------------------")
print("The List of Features and their respective importance (Rank)", end="\n")
print(mlp_results)

# Continue with the rest of the feature selection and evaluation process based on feature importance ranking
d = rfe_ranking  # Use RFE ranking instead of LGBM's feature importance
r = list(X.columns)
max_imp = max(d)
min_imp = min(d)
val = list(np.linspace(max_imp, min_imp, 50))  # Creating thresholds for selecting features
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
overall_accuracy_scores = []
list_of_predictors = []
No_of_predictors = []

for value in val:
    u = []
    columns = [u.append(r[i]) for i in range(len(d)) if d[i] <= value]  # Use ranks to select top features
    list_of_predictors.append(u)
    No_of_predictors.append(len(u))
    X_training = X_train[u]
    X_value = X_val[u]
    
    # Fitting the MLP classifier with selected features
    mlp = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=0)
    mlp.fit(X_training, y_train)
    
    y_pred = mlp.predict(X_value)
    recall = recall_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred)
    roc_auc = roc_auc_score(y_val, y_pred)
    Overall_Accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)
    
    recall_scores.append(recall)
    precision_scores.append(precision)
    roc_auc_scores.append(roc_auc)
    overall_accuracy_scores.append(Overall_Accuracy)
    f1_scores.append(f1)

# Identifying the best number of predictors based on the ROC AUC score
x = roc_auc_scores.index(max(roc_auc_scores))
optimal_predictors = ", ".join(list_of_predictors[x])

# Storing results
mlp_score_library = {
    "ROC AUC Score": round(roc_auc_scores[x], 2),
    "Recall Score": round(recall_scores[x], 2),
    "Precision Score": round(precision_scores[x], 2),
    'F1 Score': round(f1_scores[x], 2),
    "Overall Accuracy": round(overall_accuracy_scores[x], 2),
    'Optimum predictors': No_of_predictors[x],
    'list_of_predictors': optimal_predictors
}

print(mlp_score_library)
# Out:
# The Classification report for MLP Classifier
#
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      8372
#            1       0.20      0.00      0.00      1937
#
#     accuracy                           0.81     10309
#    macro avg       0.51      0.50      0.45     10309
# weighted avg       0.70      0.81      0.73     10309
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
# The List of Features and their respective importance (Rank)
#                        Feature Names  Feature Importance (Rank)
# 0                               id17                        157
# 1                               id18                        100
# 2                               id21                        171
# 3                               id55                         41
# 4                             id58_1                         44
# 5                             id58_2                         34
# 6                             id58_3                        161
# 7                               id59                        123
# 8                               id60                        122
# 9                               id61                        164
# 10                              id70                        102
# 11              ValorVehiculoMercado                        187
# 12               SINCOTotalVehiculos                         30
# 13                           DGT_001                         46
# 14                           DGT_002                         48
# 15                           DGC_001                        111
# 16                           DGC_002                         73
# 17                           DGC_003                        103
# 18                           DGC_004                         98
# 19                           DGC_005                        144
# 20                           DGC_006                         66
# 21                           DGC_007                        129
# 22                           DGC_008                         25
# 23                           DGC_009                        109
# 24                           DGC_010                         84
# 25                           DGC_011                         67
# 26                           DGC_012                         70
# 27                           DGC_013                         59
# 28                           DGC_014                         93
# 29                           DGC_015                        146
# 30                           DGC_016                         94
# 31                           DGC_017                        127
# 32                           DGC_018                         69
# 33                           DGC_019                         60
# 34                           DGC_020                        131
# 35                           INE_001                        151
# 36                           INE_002                        138
# 37                           INE_003                        115
# 38                           INE_004                        116
# 39                           INE_005                         97
# 40                           INE_006                        132
# 41                           INE_007                        165
# 42                           INE_008                        130
# 43                           INE_009                         86
# 44                           INE_010                        126
# 45                           INE_011                        181
# 46                           INE_012                         80
# 47                           INE_013                         78
# 48                           INE_014                        119
# 49                           INE_015                         72
# 50                           INE_016                         54
# 51                           INE_017                         81
# 52                           INE_018                         50
# 53                           INE_019                         53
# 54                           INE_020                         52
# 55                           INE_021                         71
# 56                           INE_022                         83
# 57                           INE_023                        189
# 58                           INE_024                        155
# 59                           INE_025                        117
# 60                           INE_026                        178
# 61                           INE_027                        166
# 62                           INE_028                        186
# 63                           INE_029                        158
# 64                           INE_030                        172
# 65                           INE_031                        179
# 66                           INE_032                        183
# 67                           INE_033                        150
# 68                           INE_034                        182
# 69                           INE_035                        147
# 70                           INE_036                        145
# 71                           INE_037                        180
# 72                           INE_038                        154
# 73                           INE_039                        149
# 74                           INE_040                        176
# 75                           INE_041                        173
# 76                           INE_042                        168
# 77                           INE_043                        185
# 78                           INE_044                        170
# 79                           INE_045                        188
# 80                           INE_046                        107
# 81                           INE_047                         75
# 82                           INE_048                        106
# 83                           INE_049                        156
# 84                           INE_050                        160
# 85                           INE_051                         96
# 86                           INE_052                        114
# 87                           INE_053                        104
# 88                           INE_054                        113
# 89                           INE_055                         79
# 90                           INE_056                         77
# 91                           INE_057                         74
# 92                           SEA_001                         45
# 93                           SEA_002                         91
# 94                           SEA_003                        125
# 95                           SEA_004                         51
# 96                           SEA_005                        105
# 97                           SEA_006                         85
# 98                           SEA_007                        141
# 99                           SEA_008                        134
# 100                          SEA_009                         58
# 101                          SEA_010                         57
# 102                          OSM_001                        140
# 103                          IGN_001                        169
# 104                          REP_001                        108
# 105                          REP_002                        128
# 106                          REP_003                         92
# 107                          REP_004                         90
# 108                          REP_005                         64
# 109                          REP_006                        101
# 110                          REP_007                         89
# 111                          REP_008                         56
# 112                          REP_009                        163
# 113                          REP_010                        120
# 114                         ScoreAda                         99
# 115                   NacionalidadID                         82
# 116                      ProvinciaID                        143
# 117                    CiaAnteriorID                        175
# 118                        ComarcaID                        110
# 119                      TiempoSINCO                        167
# 120                   PerteneceSINCO                         15
# 121             TotalMatriculasSINCO                         42
# 122                 TiempoMedioSINCO                         95
# 123                TiempoSeguroSINCO                         37
# 124                 TiempoSINCO_Anos                        184
# 125       FrecuenciaDanyosMateriales                        153
# 126       FrecuenciaDanyosPersonales                        148
# 127         FrecuenciaSiniestroSINCO                        159
# 128                NV_AutomovilSINCO                         76
# 129              NV_MotocicletaSINCO                         68
# 130                    NV_OtrosSINCO                         40
# 131                       ScoreCanal                        112
# 132                             Edad                         63
# 133                Antiguedad_Carnet                         61
# 134                       AnyoPoliza                        133
# 135               AntiguedadVehiculo                         55
# 136                             id24                         29
# 137                             id71                         39
# 138           SINCOMatriculaIncluida                          8
# 139                    ContrataLunas                         16
# 140               ContrataAsistencia                          9
# 141            ContrataDanyosPropios                         22
# 142                     Conductor2ID                         18
# 143      NumeroDanyosMaterialesSINCO                        118
# 144     ProcesoDanyosMaterialesSINCO                        121
# 145      NumeroDanyosPersonalesSINCO                        162
# 146     ProcesoDanyosPersonalesSINCO                        137
# 147                           id72_2                         10
# 148                         riesgo_0                         47
# 149                         riesgo_4                         27
# 150                         riesgo_3                         87
# 151                         riesgo_2                         35
# 152                         riesgo_1                         12
# 153                           id13_B                         26
# 154                           id13_C                         62
# 155                           id13_D                         24
# 156                           id13_E                         65
# 157                           id13_F                         43
# 158                           id13_G                         17
# 159                           id13_H                          3
# 160                           id13_I                          6
# 161                           id13_Z                          2
# 162                     id14_EXPANDE                         31
# 163                      id14_INICIA                         49
# 164               id14_MANTENIMIENTO                         11
# 165                      id14_OPTIMA                         32
# 166                 id14_OPTIMA_PLUS                        135
# 167                    id14_PROYECTA                         33
# 168            id15_AGTES_VINCULADOS                        142
# 169                  id15_CORREDORES                        174
# 170                   id15_EMPLEADOS                        136
# 171                id15_OFIC_ENTIDAD                          7
# 172              id54_ANUAL_EFECTIVO                         28
# 173       id54_SEMESTRAL_DOMICILIADO                         21
# 174          id54_SEMESTRAL_EFECTIVO                         20
# 175               Subramo_CICLOMOTOR                          4
# 176  Subramo_COMERCI_MENOS_DE_3_5TN_                         38
# 177              Subramo_MOTOCICLETA                          5
# 178  Subramo_TURISMO_NO_CUADRICICLOS                         13
# 179      Subramo_VEHICULOS_AGRICOLAS                        177
# 180   Subramo_VEHICULOS_INDUSTRIALES                        190
# 181        TipoConsultaSINCO_Tomador                         19
# 182                        NotaLUA_B                        139
# 183                        NotaLUA_C                         14
# 184                        NotaLUA_D                         88
# 185                        NotaLUA_E                         36
# 186                        NotaLUA_F                         23
# 187                        NotaLUA_G                        124
# 188                            SINCO                        152
# 189                  Cliente_Diverso                          1
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'ROC AUC Score': 0.6, 'Recall Score': 0.41, 'Precision Score': 0.31, 'F1 Score': 0.35, 'Overall Accuracy': 0.72, 'Optimum predictors': 93, 'list_of_predictors': 'id55, id58_1, id58_2, SINCOTotalVehiculos, DGT_001, DGT_002, DGC_002, DGC_006, DGC_008, DGC_010, DGC_011, DGC_012, DGC_013, DGC_014, DGC_018, DGC_019, INE_009, INE_012, INE_013, INE_015, INE_016, INE_017, INE_018, INE_019, INE_020, INE_021, INE_022, INE_047, INE_055, INE_056, INE_057, SEA_001, SEA_002, SEA_004, SEA_006, SEA_009, SEA_010, REP_003, REP_004, REP_005, REP_007, REP_008, NacionalidadID, PerteneceSINCO, TotalMatriculasSINCO, TiempoSeguroSINCO, NV_AutomovilSINCO, NV_MotocicletaSINCO, NV_OtrosSINCO, Edad, Antiguedad_Carnet, AntiguedadVehiculo, id24, id71, SINCOMatriculaIncluida, ContrataLunas, ContrataAsistencia, ContrataDanyosPropios, Conductor2ID, id72_2, riesgo_0, riesgo_4, riesgo_3, riesgo_2, riesgo_1, id13_B, id13_C, id13_D, id13_E, id13_F, id13_G, id13_H, id13_I, id13_Z, id14_EXPANDE, id14_INICIA, id14_MANTENIMIENTO, id14_OPTIMA, id14_PROYECTA, id15_OFIC_ENTIDAD, id54_ANUAL_EFECTIVO, id54_SEMESTRAL_DOMICILIADO, id54_SEMESTRAL_EFECTIVO, Subramo_CICLOMOTOR, Subramo_COMERCI_MENOS_DE_3_5TN_, Subramo_MOTOCICLETA, Subramo_TURISMO_NO_CUADRICICLOS, TipoConsultaSINCO_Tomador, NotaLUA_C, NotaLUA_D, NotaLUA_E, NotaLUA_F, Cliente_Diverso'}
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Import necessary libraries
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, recall_score, precision_score, roc_auc_score, accuracy_score, f1_score
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import numpy as np
import pandas as pd

# Fitting the MLP Classifier Algorithm on the training dataset
mlp = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=0)
mlp.fit(X_train, y_train)

# Predicting the target variable using the trained model
y_pred = mlp.predict(X_val)

# Classification Report
print("The Classification report for MLP Classifier", end = "\n\n")
print(classification_report(y_val, y_pred))

# Feature Importance using Recursive Feature Elimination (RFE)
# Logistic Regression is used here to rank features, as MLP doesn't have direct feature importance
log_reg = LogisticRegression(max_iter=1000)
rfe = RFE(estimator=log_reg, n_features_to_select=1)
rfe.fit(X_train, y_train)

# Importance of each attribute/features
rfe_ranking = rfe.ranking_
mlp_results = pd.DataFrame(X_train.columns)
mlp_results.rename(columns={0: "Feature Names"}, inplace=True)
mlp_results['Feature Importance (Rank)'] = rfe_ranking
print("----------------------------------------------------")
print("The List of Features and their respective importance (Rank)", end="\n")
print(mlp_results)

# Continue with the rest of the feature selection and evaluation process based on feature importance ranking
d = rfe_ranking  # Use RFE ranking instead of LGBM's feature importance
r = list(X.columns)
max_imp = max(d)
min_imp = min(d)
val = list(np.linspace(max_imp, min_imp, 50))  # Creating thresholds for selecting features
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
overall_accuracy_scores = []
list_of_predictors = []
No_of_predictors = []

for value in val:
    u = []
    columns = [u.append(r[i]) for i in range(len(d)) if d[i] <= value]  # Use ranks to select top features
    list_of_predictors.append(u)
    No_of_predictors.append(len(u))
    X_training = X_train[u]
    X_value = X_val[u]
    
    # Fitting the MLP classifier with selected features
    mlp = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500, random_state=0)
    mlp.fit(X_training, y_train)
    
    y_pred = mlp.predict(X_value)
    recall = recall_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred)
    roc_auc = roc_auc_score(y_val, y_pred)
    Overall_Accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)
    
    recall_scores.append(recall)
    precision_scores.append(precision)
    roc_auc_scores.append(roc_auc)
    overall_accuracy_scores.append(Overall_Accuracy)
    f1_scores.append(f1)

# Identifying the best number of predictors based on the ROC AUC score
x = roc_auc_scores.index(max(roc_auc_scores))
optimal_predictors = ", ".join(list_of_predictors[x])

# Storing results
mlp_score_library = {
    "ROC AUC Score": round(roc_auc_scores[x], 2),
    "Recall Score": round(recall_scores[x], 2),
    "Precision Score": round(precision_scores[x], 2),
    'F1 Score': round(f1_scores[x], 2),
    "Overall Accuracy": round(overall_accuracy_scores[x], 2),
    'Optimum predictors': No_of_predictors[x],
    'list_of_predictors': optimal_predictors
}

# Print the results in the desired format
print(mlp_score_library)
# Out:
# The Classification report for MLP Classifier
#
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      8372
#            1       0.20      0.00      0.00      1937
#
#     accuracy                           0.81     10309
#    macro avg       0.51      0.50      0.45     10309
# weighted avg       0.70      0.81      0.73     10309
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
# The List of Features and their respective importance (Rank)
#                        Feature Names  Feature Importance (Rank)
# 0                               id17                        157
# 1                               id18                        100
# 2                               id21                        171
# 3                               id55                         41
# 4                             id58_1                         44
# 5                             id58_2                         34
# 6                             id58_3                        161
# 7                               id59                        123
# 8                               id60                        122
# 9                               id61                        164
# 10                              id70                        102
# 11              ValorVehiculoMercado                        187
# 12               SINCOTotalVehiculos                         30
# 13                           DGT_001                         46
# 14                           DGT_002                         48
# 15                           DGC_001                        111
# 16                           DGC_002                         73
# 17                           DGC_003                        103
# 18                           DGC_004                         98
# 19                           DGC_005                        144
# 20                           DGC_006                         66
# 21                           DGC_007                        129
# 22                           DGC_008                         25
# 23                           DGC_009                        109
# 24                           DGC_010                         84
# 25                           DGC_011                         67
# 26                           DGC_012                         70
# 27                           DGC_013                         59
# 28                           DGC_014                         93
# 29                           DGC_015                        146
# 30                           DGC_016                         94
# 31                           DGC_017                        127
# 32                           DGC_018                         69
# 33                           DGC_019                         60
# 34                           DGC_020                        131
# 35                           INE_001                        151
# 36                           INE_002                        138
# 37                           INE_003                        115
# 38                           INE_004                        116
# 39                           INE_005                         97
# 40                           INE_006                        132
# 41                           INE_007                        165
# 42                           INE_008                        130
# 43                           INE_009                         86
# 44                           INE_010                        126
# 45                           INE_011                        181
# 46                           INE_012                         80
# 47                           INE_013                         78
# 48                           INE_014                        119
# 49                           INE_015                         72
# 50                           INE_016                         54
# 51                           INE_017                         81
# 52                           INE_018                         50
# 53                           INE_019                         53
# 54                           INE_020                         52
# 55                           INE_021                         71
# 56                           INE_022                         83
# 57                           INE_023                        189
# 58                           INE_024                        155
# 59                           INE_025                        117
# 60                           INE_026                        178
# 61                           INE_027                        166
# 62                           INE_028                        186
# 63                           INE_029                        158
# 64                           INE_030                        172
# 65                           INE_031                        179
# 66                           INE_032                        183
# 67                           INE_033                        150
# 68                           INE_034                        182
# 69                           INE_035                        147
# 70                           INE_036                        145
# 71                           INE_037                        180
# 72                           INE_038                        154
# 73                           INE_039                        149
# 74                           INE_040                        176
# 75                           INE_041                        173
# 76                           INE_042                        168
# 77                           INE_043                        185
# 78                           INE_044                        170
# 79                           INE_045                        188
# 80                           INE_046                        107
# 81                           INE_047                         75
# 82                           INE_048                        106
# 83                           INE_049                        156
# 84                           INE_050                        160
# 85                           INE_051                         96
# 86                           INE_052                        114
# 87                           INE_053                        104
# 88                           INE_054                        113
# 89                           INE_055                         79
# 90                           INE_056                         77
# 91                           INE_057                         74
# 92                           SEA_001                         45
# 93                           SEA_002                         91
# 94                           SEA_003                        125
# 95                           SEA_004                         51
# 96                           SEA_005                        105
# 97                           SEA_006                         85
# 98                           SEA_007                        141
# 99                           SEA_008                        134
# 100                          SEA_009                         58
# 101                          SEA_010                         57
# 102                          OSM_001                        140
# 103                          IGN_001                        169
# 104                          REP_001                        108
# 105                          REP_002                        128
# 106                          REP_003                         92
# 107                          REP_004                         90
# 108                          REP_005                         64
# 109                          REP_006                        101
# 110                          REP_007                         89
# 111                          REP_008                         56
# 112                          REP_009                        163
# 113                          REP_010                        120
# 114                         ScoreAda                         99
# 115                   NacionalidadID                         82
# 116                      ProvinciaID                        143
# 117                    CiaAnteriorID                        175
# 118                        ComarcaID                        110
# 119                      TiempoSINCO                        167
# 120                   PerteneceSINCO                         15
# 121             TotalMatriculasSINCO                         42
# 122                 TiempoMedioSINCO                         95
# 123                TiempoSeguroSINCO                         37
# 124                 TiempoSINCO_Anos                        184
# 125       FrecuenciaDanyosMateriales                        153
# 126       FrecuenciaDanyosPersonales                        148
# 127         FrecuenciaSiniestroSINCO                        159
# 128                NV_AutomovilSINCO                         76
# 129              NV_MotocicletaSINCO                         68
# 130                    NV_OtrosSINCO                         40
# 131                       ScoreCanal                        112
# 132                             Edad                         63
# 133                Antiguedad_Carnet                         61
# 134                       AnyoPoliza                        133
# 135               AntiguedadVehiculo                         55
# 136                             id24                         29
# 137                             id71                         39
# 138           SINCOMatriculaIncluida                          8
# 139                    ContrataLunas                         16
# 140               ContrataAsistencia                          9
# 141            ContrataDanyosPropios                         22
# 142                     Conductor2ID                         18
# 143      NumeroDanyosMaterialesSINCO                        118
# 144     ProcesoDanyosMaterialesSINCO                        121
# 145      NumeroDanyosPersonalesSINCO                        162
# 146     ProcesoDanyosPersonalesSINCO                        137
# 147                           id72_2                         10
# 148                         riesgo_0                         47
# 149                         riesgo_4                         27
# 150                         riesgo_3                         87
# 151                         riesgo_2                         35
# 152                         riesgo_1                         12
# 153                           id13_B                         26
# 154                           id13_C                         62
# 155                           id13_D                         24
# 156                           id13_E                         65
# 157                           id13_F                         43
# 158                           id13_G                         17
# 159                           id13_H                          3
# 160                           id13_I                          6
# 161                           id13_Z                          2
# 162                     id14_EXPANDE                         31
# 163                      id14_INICIA                         49
# 164               id14_MANTENIMIENTO                         11
# 165                      id14_OPTIMA                         32
# 166                 id14_OPTIMA_PLUS                        135
# 167                    id14_PROYECTA                         33
# 168            id15_AGTES_VINCULADOS                        142
# 169                  id15_CORREDORES                        174
# 170                   id15_EMPLEADOS                        136
# 171                id15_OFIC_ENTIDAD                          7
# 172              id54_ANUAL_EFECTIVO                         28
# 173       id54_SEMESTRAL_DOMICILIADO                         21
# 174          id54_SEMESTRAL_EFECTIVO                         20
# 175               Subramo_CICLOMOTOR                          4
# 176  Subramo_COMERCI_MENOS_DE_3_5TN_                         38
# 177              Subramo_MOTOCICLETA                          5
# 178  Subramo_TURISMO_NO_CUADRICICLOS                         13
# 179      Subramo_VEHICULOS_AGRICOLAS                        177
# 180   Subramo_VEHICULOS_INDUSTRIALES                        190
# 181        TipoConsultaSINCO_Tomador                         19
# 182                        NotaLUA_B                        139
# 183                        NotaLUA_C                         14
# 184                        NotaLUA_D                         88
# 185                        NotaLUA_E                         36
# 186                        NotaLUA_F                         23
# 187                        NotaLUA_G                        124
# 188                            SINCO                        152
# 189                  Cliente_Diverso                          1
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'ROC AUC Score': 0.6, 'Recall Score': 0.41, 'Precision Score': 0.31, 'F1 Score': 0.35, 'Overall Accuracy': 0.72, 'Optimum predictors': 93, 'list_of_predictors': 'id55, id58_1, id58_2, SINCOTotalVehiculos, DGT_001, DGT_002, DGC_002, DGC_006, DGC_008, DGC_010, DGC_011, DGC_012, DGC_013, DGC_014, DGC_018, DGC_019, INE_009, INE_012, INE_013, INE_015, INE_016, INE_017, INE_018, INE_019, INE_020, INE_021, INE_022, INE_047, INE_055, INE_056, INE_057, SEA_001, SEA_002, SEA_004, SEA_006, SEA_009, SEA_010, REP_003, REP_004, REP_005, REP_007, REP_008, NacionalidadID, PerteneceSINCO, TotalMatriculasSINCO, TiempoSeguroSINCO, NV_AutomovilSINCO, NV_MotocicletaSINCO, NV_OtrosSINCO, Edad, Antiguedad_Carnet, AntiguedadVehiculo, id24, id71, SINCOMatriculaIncluida, ContrataLunas, ContrataAsistencia, ContrataDanyosPropios, Conductor2ID, id72_2, riesgo_0, riesgo_4, riesgo_3, riesgo_2, riesgo_1, id13_B, id13_C, id13_D, id13_E, id13_F, id13_G, id13_H, id13_I, id13_Z, id14_EXPANDE, id14_INICIA, id14_MANTENIMIENTO, id14_OPTIMA, id14_PROYECTA, id15_OFIC_ENTIDAD, id54_ANUAL_EFECTIVO, id54_SEMESTRAL_DOMICILIADO, id54_SEMESTRAL_EFECTIVO, Subramo_CICLOMOTOR, Subramo_COMERCI_MENOS_DE_3_5TN_, Subramo_MOTOCICLETA, Subramo_TURISMO_NO_CUADRICICLOS, TipoConsultaSINCO_Tomador, NotaLUA_C, NotaLUA_D, NotaLUA_E, NotaLUA_F, Cliente_Diverso'}

# %%
# Import necessary libraries
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, recall_score, precision_score, roc_auc_score, accuracy_score, f1_score
from sklearn.feature_selection import RFE
import numpy as np
import pandas as pd

# Fitting the Logistic Regression Algorithm on the training dataset
log_reg = LogisticRegression(max_iter=500, random_state=0)
log_reg.fit(X_train, y_train)

# Predicting the target variable using the trained model
y_pred = log_reg.predict(X_val)

# Classification Report for Logistic Regression
print("The Classification report for Logistic Regression", end="\n\n")
print(classification_report(y_val, y_pred))

# Feature Importance using Recursive Feature Elimination (RFE)
rfe = RFE(estimator=log_reg, n_features_to_select=1)  # RFE with Logistic Regression to rank features
rfe.fit(X_train, y_train)

# Importance of each attribute/features
rfe_ranking = rfe.ranking_
logreg_results = pd.DataFrame(X_train.columns)
logreg_results.rename(columns={0: "Feature Names"}, inplace=True)
logreg_results['Feature Importance (Rank)'] = rfe_ranking
print("----------------------------------------------------")
print("The List of Features and their respective importance (Rank)", end="\n")
print(logreg_results)

# Continue with the rest of the feature selection and evaluation process based on feature importance ranking
d = rfe_ranking  # Use RFE ranking instead of MLP's feature importance
r = list(X.columns)
max_imp = max(d)
min_imp = min(d)
val = list(np.linspace(max_imp, min_imp, 50))  # Creating thresholds for selecting features
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
overall_accuracy_scores = []
list_of_predictors = []
No_of_predictors = []

for value in val:
    u = []
    columns = [u.append(r[i]) for i in range(len(d)) if d[i] <= value]  # Use ranks to select top features
    list_of_predictors.append(u)
    No_of_predictors.append(len(u))
    X_training = X_train[u]
    X_value = X_val[u]
    
    # Fitting the Logistic Regression classifier with selected features
    log_reg = LogisticRegression(max_iter=500, random_state=0)
    log_reg.fit(X_training, y_train)
    
    y_pred = log_reg.predict(X_value)
    recall = recall_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred)
    roc_auc = roc_auc_score(y_val, y_pred)
    Overall_Accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)
    
    recall_scores.append(recall)
    precision_scores.append(precision)
    roc_auc_scores.append(roc_auc)
    overall_accuracy_scores.append(Overall_Accuracy)
    f1_scores.append(f1)

# Identifying the best number of predictors based on the ROC AUC score
x = roc_auc_scores.index(max(roc_auc_scores))
optimal_predictors = ", ".join(list_of_predictors[x])

# Storing results
logreg_score_library = {
    "ROC AUC Score": round(roc_auc_scores[x], 2),
    "Recall Score": round(recall_scores[x], 2),
    "Precision Score": round(precision_scores[x], 2),
    'F1 Score': round(f1_scores[x], 2),
    "Overall Accuracy": round(overall_accuracy_scores[x], 2),
    'Optimum predictors': No_of_predictors[x],
    'list_of_predictors': optimal_predictors
}

# Print the results in the desired format
print(logreg_score_library)
# Out:
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# The Classification report for Logistic Regression
#
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      8372
#            1       0.00      0.00      0.00      1937
#
#     accuracy                           0.81     10309
#    macro avg       0.41      0.50      0.45     10309
# weighted avg       0.66      0.81      0.73     10309
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# {'ROC AUC Score': 0.52, 'Recall Score': 0.04, 'Precision Score': 0.58, 'F1 Score': 0.07, 'Overall Accuracy': 0.81, 'Optimum predictors': 55, 'list_of_predictors': 'id55, id58_1, id58_2, SINCOTotalVehiculos, DGT_001, DGT_002, DGC_008, DGC_014, DGC_015, DGC_016, INE_008, SEA_009, SEA_010, REP_002, REP_003, REP_008, TotalMatriculasSINCO, NV_OtrosSINCO, AntiguedadVehiculo, id24, id71, SINCOMatriculaIncluida, ContrataLunas, ContrataAsistencia, ContrataDanyosPropios, Conductor2ID, NumeroDanyosMaterialesSINCO, id72_2, riesgo_4, riesgo_2, id13_C, id13_D, id13_E, id13_F, id13_H, id13_I, id14_EXPANDE, id14_INICIA, id14_MANTENIMIENTO, id14_OPTIMA, id14_PROYECTA, id15_OFIC_ENTIDAD, id54_ANUAL_EFECTIVO, id54_SEMESTRAL_DOMICILIADO, id54_SEMESTRAL_EFECTIVO, Subramo_CICLOMOTOR, Subramo_COMERCI_MENOS_DE_3_5TN_, Subramo_MOTOCICLETA, Subramo_TURISMO_NO_CUADRICICLOS, TipoConsultaSINCO_Tomador, NotaLUA_C, NotaLUA_D, NotaLUA_E, NotaLUA_F, Cliente_Diverso'}
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Nishant Moona\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Decision Tree Classifier

# %%
# Fitting the LGBM Classifier Algorithm on the training dataset

dtc = DecisionTreeClassifier()
dtc.fit(X_train,y_train)

# Predicting the target variable using the trained model

y_pred = dtc.predict(X_val)

# Classification Report

print("The Classification report for Decision Tree Classifier", end = "\n\n")
print(classification_report(y_val, y_pred))

# Importance of each attribute/features

dtc_results = pd.DataFrame(X_train.columns)
dtc_results.rename(columns = {0:"Feature Names"}, inplace = True)
dtc_results['Feature Importance'] = dtc.feature_importances_
print("----------------------------------------------------")
print("The List of Features and their respective importance", end = "\n")
dtc_results
# Out:
# The Classification report for Decision Tree Classifier
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      8372
#            1       0.30      0.33      0.32      1937
#
#     accuracy                           0.73     10309
#    macro avg       0.57      0.58      0.57     10309
# weighted avg       0.74      0.73      0.74     10309
#
# ----------------------------------------------------
# The List of Features and their respective importance
#                        Feature Names  Feature Importance
# 0                               id17            0.003554
# 1                               id18            0.013457
# 2                               id21            0.005362
# 3                               id55            0.070583
# 4                             id58_1            0.002390
# 5                             id58_2            0.006504
# 6                             id58_3            0.002207
# 7                               id59            0.004628
# 8                               id60            0.005803
# 9                               id61            0.008163
# 10                              id70            0.023391
# 11              ValorVehiculoMercado            0.030277
# 12               SINCOTotalVehiculos            0.013489
# 13                           DGT_001            0.003240
# 14                           DGT_002            0.006602
# 15                           DGC_001            0.004374
# 16                           DGC_002            0.004167
# 17                           DGC_003            0.003627
# 18                           DGC_004            0.003820
# 19                           DGC_005            0.003602
# 20                           DGC_006            0.004998
# 21                           DGC_007            0.005199
# 22                           DGC_008            0.004985
# 23                           DGC_009            0.006430
# 24                           DGC_010            0.003748
# 25                           DGC_011            0.004329
# 26                           DGC_012            0.004537
# 27                           DGC_013            0.002834
# 28                           DGC_014            0.004278
# 29                           DGC_015            0.003551
# 30                           DGC_016            0.004568
# 31                           DGC_017            0.006451
# 32                           DGC_018            0.004853
# 33                           DGC_019            0.005423
# 34                           DGC_020            0.003657
# 35                           INE_001            0.002152
# 36                           INE_002            0.001954
# 37                           INE_003            0.002262
# 38                           INE_004            0.001416
# 39                           INE_005            0.004227
# 40                           INE_006            0.003099
# 41                           INE_007            0.004794
# 42                           INE_008            0.002522
# 43                           INE_009            0.007722
# 44                           INE_010            0.003552
# 45                           INE_011            0.003493
# 46                           INE_012            0.006748
# 47                           INE_013            0.001796
# 48                           INE_014            0.001511
# 49                           INE_015            0.001301
# 50                           INE_016            0.003935
# 51                           INE_017            0.001391
# 52                           INE_018            0.005494
# 53                           INE_019            0.002836
# 54                           INE_020            0.002823
# 55                           INE_021            0.002492
# 56                           INE_022            0.003777
# 57                           INE_023            0.002604
# 58                           INE_024            0.002631
# 59                           INE_025            0.001952
# 60                           INE_026            0.002363
# 61                           INE_027            0.005473
# 62                           INE_028            0.000358
# 63                           INE_029            0.002303
# 64                           INE_030            0.001171
# 65                           INE_031            0.001341
# 66                           INE_032            0.002602
# 67                           INE_033            0.003193
# 68                           INE_034            0.005158
# 69                           INE_035            0.004764
# 70                           INE_036            0.003004
# 71                           INE_037            0.003898
# 72                           INE_038            0.004006
# 73                           INE_039            0.003224
# 74                           INE_040            0.004054
# 75                           INE_041            0.003492
# 76                           INE_042            0.005468
# 77                           INE_043            0.003226
# 78                           INE_044            0.003843
# 79                           INE_045            0.005909
# 80                           INE_046            0.002545
# 81                           INE_047            0.001041
# 82                           INE_048            0.003802
# 83                           INE_049            0.002158
# 84                           INE_050            0.002845
# 85                           INE_051            0.003275
# 86                           INE_052            0.001032
# 87                           INE_053            0.002271
# 88                           INE_054            0.003537
# 89                           INE_055            0.005250
# 90                           INE_056            0.003229
# 91                           INE_057            0.005767
# 92                           SEA_001            0.007057
# 93                           SEA_002            0.007236
# 94                           SEA_003            0.009052
# 95                           SEA_004            0.005485
# 96                           SEA_005            0.006185
# 97                           SEA_006            0.008220
# 98                           SEA_007            0.006902
# 99                           SEA_008            0.007946
# 100                          SEA_009            0.010175
# 101                          SEA_010            0.006977
# 102                          OSM_001            0.004604
# 103                          IGN_001            0.002003
# 104                          REP_001            0.001493
# 105                          REP_002            0.001588
# 106                          REP_003            0.002106
# 107                          REP_004            0.004939
# 108                          REP_005            0.004936
# 109                          REP_006            0.005280
# 110                          REP_007            0.003757
# 111                          REP_008            0.005072
# 112                          REP_009            0.004665
# 113                          REP_010            0.006369
# 114                         ScoreAda            0.013248
# 115                   NacionalidadID            0.004444
# 116                      ProvinciaID            0.000967
# 117                    CiaAnteriorID            0.018377
# 118                        ComarcaID            0.002609
# 119                      TiempoSINCO            0.010694
# 120                   PerteneceSINCO            0.017353
# 121             TotalMatriculasSINCO            0.009051
# 122                 TiempoMedioSINCO            0.029942
# 123                TiempoSeguroSINCO            0.014978
# 124                 TiempoSINCO_Anos            0.013000
# 125       FrecuenciaDanyosMateriales            0.007546
# 126       FrecuenciaDanyosPersonales            0.003537
# 127         FrecuenciaSiniestroSINCO            0.028714
# 128                NV_AutomovilSINCO            0.009200
# 129              NV_MotocicletaSINCO            0.003602
# 130                    NV_OtrosSINCO            0.003278
# 131                       ScoreCanal            0.017167
# 132                             Edad            0.022153
# 133                Antiguedad_Carnet            0.023794
# 134                       AnyoPoliza            0.036261
# 135               AntiguedadVehiculo            0.022320
# 136                             id24            0.000156
# 137                             id71            0.006780
# 138           SINCOMatriculaIncluida            0.007679
# 139                    ContrataLunas            0.001291
# 140               ContrataAsistencia            0.001296
# 141            ContrataDanyosPropios            0.001845
# 142                     Conductor2ID            0.003738
# 143      NumeroDanyosMaterialesSINCO            0.003187
# 144     ProcesoDanyosMaterialesSINCO            0.001103
# 145      NumeroDanyosPersonalesSINCO            0.000623
# 146     ProcesoDanyosPersonalesSINCO            0.000457
# 147                           id72_2            0.002861
# 148                         riesgo_0            0.001813
# 149                         riesgo_4            0.001153
# 150                         riesgo_3            0.001359
# 151                         riesgo_2            0.004063
# 152                         riesgo_1            0.000551
# 153                           id13_B            0.001253
# 154                           id13_C            0.001078
# 155                           id13_D            0.001113
# 156                           id13_E            0.001939
# 157                           id13_F            0.001754
# 158                           id13_G            0.002748
# 159                           id13_H            0.003202
# 160                           id13_I            0.000990
# 161                           id13_Z            0.000361
# 162                     id14_EXPANDE            0.000751
# 163                      id14_INICIA            0.000628
# 164               id14_MANTENIMIENTO            0.000626
# 165                      id14_OPTIMA            0.000449
# 166                 id14_OPTIMA_PLUS            0.000318
# 167                    id14_PROYECTA            0.002385
# 168            id15_AGTES_VINCULADOS            0.000819
# 169                  id15_CORREDORES            0.001561
# 170                   id15_EMPLEADOS            0.000198
# 171                id15_OFIC_ENTIDAD            0.000578
# 172              id54_ANUAL_EFECTIVO            0.003482
# 173       id54_SEMESTRAL_DOMICILIADO            0.002416
# 174          id54_SEMESTRAL_EFECTIVO            0.001413
# 175               Subramo_CICLOMOTOR            0.000196
# 176  Subramo_COMERCI_MENOS_DE_3_5TN_            0.001372
# 177              Subramo_MOTOCICLETA            0.001004
# 178  Subramo_TURISMO_NO_CUADRICICLOS            0.001486
# 179      Subramo_VEHICULOS_AGRICOLAS            0.000000
# 180   Subramo_VEHICULOS_INDUSTRIALES            0.000000
# 181        TipoConsultaSINCO_Tomador            0.003482
# 182                        NotaLUA_B            0.000389
# 183                        NotaLUA_C            0.000000
# 184                        NotaLUA_D            0.001960
# 185                        NotaLUA_E            0.001325
# 186                        NotaLUA_F            0.001330
# 187                        NotaLUA_G            0.001545
# 188                            SINCO            0.000000
# 189                  Cliente_Diverso            0.008443

# %%
d = dtc.feature_importances_
r = list(X.columns)
max_imp = max(d)
min_imp = min(d)
val = list(np.linspace(max_imp, min_imp, 50))
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
overall_accuracy_scores = []
list_of_predictors = []
No_of_predictors = []
for value in val:
    u = []
    columns = [u.append(r[i]) for i in range(len(d)) if d[i] >= value]
    # 
    list_of_predictors.append(u)
    No_of_predictors.append(len(u))
    X_training = X_train[u]
    X_value = X_val[u]
    # 
    
    dtc = DecisionTreeClassifier()
    dtc.fit(X_training,y_train)
    y_pred = dtc.predict(X_value)
    recall = recall_score(y_val,y_pred)
    precision = precision_score(y_val,y_pred)
    roc_auc = roc_auc_score(y_val,y_pred)
    Overall_Accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val,y_pred)
    recall_scores.append(recall)
    precision_scores.append(precision)
    roc_auc_scores.append(roc_auc)
    overall_accuracy_scores.append(Overall_Accuracy)
    f1_scores.append(f1)

# %%
# Plotting the values against
metrics = [precision_scores,recall_scores,roc_auc_scores,f1_scores,overall_accuracy_scores]
metrics_name = ['precision_scores','recall_scores','roc_auc_scores','f1_scores','overall_accuracy_scores']
for k in range(len(metrics)):
    x_val = [str(i) for i in No_of_predictors]
    y_value = metrics[k].copy()
    plt.figure(figsize = (12,5))
    sns.lineplot(x = x_val, y = y_value)
    plt.xlabel("No. of Predictors")
    plt.ylabel(metrics_name[k])
    plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x = roc_auc_scores.index(max(roc_auc_scores))
detc = ", ".join(list_of_predictors[x])
detc_score_library = {"ROC AUC Score":round(roc_auc_scores[x],2),"Recall Score":round(recall_scores[x],2),'Precision Score':round(precision_scores[x],2), 'F1 Score':round(f1_scores[x],2), "Overall Accuracy":round(overall_accuracy_scores[x],2),'Optimum predictors':No_of_predictors[x], 'list_of_predictors':detc}
list_of_models.append('Decision Tree Classifier')
print(detc_score_library)
# Out:
# {'ROC AUC Score': 0.58, 'Recall Score': 0.33, 'Precision Score': 0.3, 'F1 Score': 0.31, 'Overall Accuracy': 0.73, 'Optimum predictors': 17, 'list_of_predictors': 'id18, id55, id70, ValorVehiculoMercado, SINCOTotalVehiculos, ScoreAda, CiaAnteriorID, PerteneceSINCO, TiempoMedioSINCO, TiempoSeguroSINCO, TiempoSINCO_Anos, FrecuenciaSiniestroSINCO, ScoreCanal, Edad, Antiguedad_Carnet, AnyoPoliza, AntiguedadVehiculo'}

# %%
combined_model_library.append(detc_score_library)

# %% [markdown]
# ## Extra Trees Classifier

# %%
# Fitting the Extra Tree Classifier Algorithm on the training dataset

etc = ExtraTreesClassifier(n_jobs = -1)
etc.fit(X_train,y_train)

# Predicting the target variable using the trained model

y_pred = etc.predict(X_val)

# Classification Report

print("The Classification report for Extra Tree Classifier", end = "\n\n")
print(classification_report(y_val, y_pred))

# Importance of each attribute/features

etc_results = pd.DataFrame(X_train.columns)
etc_results.rename(columns = {0:"Feature Names"}, inplace = True)
etc_results['Feature Importance'] = etc.feature_importances_
print("----------------------------------------------------")
print("The List of Features and their respective importance", end = "\n")
etc_results
# Out:
# The Classification report for Extra Tree Classifier
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89      8372
#            1       0.39      0.02      0.04      1937
#
#     accuracy                           0.81     10309
#    macro avg       0.60      0.51      0.47     10309
# weighted avg       0.74      0.81      0.73     10309
#
# ----------------------------------------------------
# The List of Features and their respective importance
#                        Feature Names  Feature Importance
# 0                               id17            0.006282
# 1                               id18            0.008401
# 2                               id21            0.004238
# 3                               id55            0.026074
# 4                             id58_1            0.007321
# 5                             id58_2            0.009592
# 6                             id58_3            0.004199
# 7                               id59            0.006653
# 8                               id60            0.006622
# 9                               id61            0.006390
# 10                              id70            0.013729
# 11              ValorVehiculoMercado            0.014073
# 12               SINCOTotalVehiculos            0.012802
# 13                           DGT_001            0.004365
# 14                           DGT_002            0.004224
# 15                           DGC_001            0.004319
# 16                           DGC_002            0.004392
# 17                           DGC_003            0.004243
# 18                           DGC_004            0.004147
# 19                           DGC_005            0.004265
# 20                           DGC_006            0.004260
# 21                           DGC_007            0.004442
# 22                           DGC_008            0.004715
# 23                           DGC_009            0.004386
# 24                           DGC_010            0.004325
# 25                           DGC_011            0.004456
# 26                           DGC_012            0.004689
# 27                           DGC_013            0.003985
# 28                           DGC_014            0.004507
# 29                           DGC_015            0.004491
# 30                           DGC_016            0.004616
# 31                           DGC_017            0.004659
# 32                           DGC_018            0.004524
# 33                           DGC_019            0.004410
# 34                           DGC_020            0.004188
# 35                           INE_001            0.004201
# 36                           INE_002            0.004200
# 37                           INE_003            0.004278
# 38                           INE_004            0.004141
# 39                           INE_005            0.004263
# 40                           INE_006            0.004047
# 41                           INE_007            0.004225
# 42                           INE_008            0.004145
# 43                           INE_009            0.004389
# 44                           INE_010            0.004196
# 45                           INE_011            0.004192
# 46                           INE_012            0.004394
# 47                           INE_013            0.004002
# 48                           INE_014            0.004097
# 49                           INE_015            0.004089
# 50                           INE_016            0.004180
# 51                           INE_017            0.004023
# 52                           INE_018            0.004565
# 53                           INE_019            0.004495
# 54                           INE_020            0.004276
# 55                           INE_021            0.004076
# 56                           INE_022            0.004009
# 57                           INE_023            0.004289
# 58                           INE_024            0.004236
# 59                           INE_025            0.004075
# 60                           INE_026            0.004107
# 61                           INE_027            0.004205
# 62                           INE_028            0.003827
# 63                           INE_029            0.004044
# 64                           INE_030            0.003877
# 65                           INE_031            0.004152
# 66                           INE_032            0.004245
# 67                           INE_033            0.004079
# 68                           INE_034            0.004552
# 69                           INE_035            0.004120
# 70                           INE_036            0.004104
# 71                           INE_037            0.004382
# 72                           INE_038            0.004302
# 73                           INE_039            0.004117
# 74                           INE_040            0.004134
# 75                           INE_041            0.004168
# 76                           INE_042            0.004230
# 77                           INE_043            0.004076
# 78                           INE_044            0.004118
# 79                           INE_045            0.004199
# 80                           INE_046            0.004020
# 81                           INE_047            0.003904
# 82                           INE_048            0.004195
# 83                           INE_049            0.004082
# 84                           INE_050            0.003899
# 85                           INE_051            0.004220
# 86                           INE_052            0.003910
# 87                           INE_053            0.003896
# 88                           INE_054            0.003862
# 89                           INE_055            0.004050
# 90                           INE_056            0.004233
# 91                           INE_057            0.004157
# 92                           SEA_001            0.005688
# 93                           SEA_002            0.005570
# 94                           SEA_003            0.005763
# 95                           SEA_004            0.005903
# 96                           SEA_005            0.005526
# 97                           SEA_006            0.005438
# 98                           SEA_007            0.005795
# 99                           SEA_008            0.005697
# 100                          SEA_009            0.005972
# 101                          SEA_010            0.005808
# 102                          OSM_001            0.004464
# 103                          IGN_001            0.004393
# 104                          REP_001            0.004397
# 105                          REP_002            0.004146
# 106                          REP_003            0.004215
# 107                          REP_004            0.004475
# 108                          REP_005            0.004412
# 109                          REP_006            0.004415
# 110                          REP_007            0.004282
# 111                          REP_008            0.004680
# 112                          REP_009            0.004088
# 113                          REP_010            0.004404
# 114                         ScoreAda            0.009917
# 115                   NacionalidadID            0.005619
# 116                      ProvinciaID            0.003637
# 117                    CiaAnteriorID            0.012461
# 118                        ComarcaID            0.004176
# 119                      TiempoSINCO            0.012997
# 120                   PerteneceSINCO            0.008551
# 121             TotalMatriculasSINCO            0.012054
# 122                 TiempoMedioSINCO            0.015872
# 123                TiempoSeguroSINCO            0.012830
# 124                 TiempoSINCO_Anos            0.012667
# 125       FrecuenciaDanyosMateriales            0.008293
# 126       FrecuenciaDanyosPersonales            0.002957
# 127         FrecuenciaSiniestroSINCO            0.008221
# 128                NV_AutomovilSINCO            0.012285
# 129              NV_MotocicletaSINCO            0.008642
# 130                    NV_OtrosSINCO            0.004530
# 131                       ScoreCanal            0.008988
# 132                             Edad            0.013358
# 133                Antiguedad_Carnet            0.013338
# 134                       AnyoPoliza            0.015757
# 135               AntiguedadVehiculo            0.013277
# 136                             id24            0.002512
# 137                             id71            0.009671
# 138           SINCOMatriculaIncluida            0.010894
# 139                    ContrataLunas            0.003025
# 140               ContrataAsistencia            0.002505
# 141            ContrataDanyosPropios            0.005753
# 142                     Conductor2ID            0.006110
# 143      NumeroDanyosMaterialesSINCO            0.007793
# 144     ProcesoDanyosMaterialesSINCO            0.002879
# 145      NumeroDanyosPersonalesSINCO            0.002629
# 146     ProcesoDanyosPersonalesSINCO            0.001482
# 147                           id72_2            0.007668
# 148                         riesgo_0            0.005128
# 149                         riesgo_4            0.001916
# 150                         riesgo_3            0.003301
# 151                         riesgo_2            0.004027
# 152                         riesgo_1            0.001018
# 153                           id13_B            0.004015
# 154                           id13_C            0.005771
# 155                           id13_D            0.006030
# 156                           id13_E            0.007598
# 157                           id13_F            0.005791
# 158                           id13_G            0.003385
# 159                           id13_H            0.003663
# 160                           id13_I            0.001379
# 161                           id13_Z            0.000501
# 162                     id14_EXPANDE            0.004047
# 163                      id14_INICIA            0.002047
# 164               id14_MANTENIMIENTO            0.001152
# 165                      id14_OPTIMA            0.004861
# 166                 id14_OPTIMA_PLUS            0.001018
# 167                    id14_PROYECTA            0.006098
# 168            id15_AGTES_VINCULADOS            0.002315
# 169                  id15_CORREDORES            0.005389
# 170                   id15_EMPLEADOS            0.000495
# 171                id15_OFIC_ENTIDAD            0.000876
# 172              id54_ANUAL_EFECTIVO            0.006561
# 173       id54_SEMESTRAL_DOMICILIADO            0.006161
# 174          id54_SEMESTRAL_EFECTIVO            0.001770
# 175               Subramo_CICLOMOTOR            0.000777
# 176  Subramo_COMERCI_MENOS_DE_3_5TN_            0.003648
# 177              Subramo_MOTOCICLETA            0.001357
# 178  Subramo_TURISMO_NO_CUADRICICLOS            0.003493
# 179      Subramo_VEHICULOS_AGRICOLAS            0.000000
# 180   Subramo_VEHICULOS_INDUSTRIALES            0.000000
# 181        TipoConsultaSINCO_Tomador            0.002857
# 182                        NotaLUA_B            0.001710
# 183                        NotaLUA_C            0.002748
# 184                        NotaLUA_D            0.004410
# 185                        NotaLUA_E            0.005422
# 186                        NotaLUA_F            0.004684
# 187                        NotaLUA_G            0.003171
# 188                            SINCO            0.000000
# 189                  Cliente_Diverso            0.017000

# %%
d = etc.feature_importances_
r = list(X.columns)
max_imp = max(d)
min_imp = min(d)
val = list(np.linspace(max_imp, min_imp, 50))
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
overall_accuracy_scores = []
list_of_predictors = []
No_of_predictors = []
for value in val:
    u = []
    columns = [u.append(r[i]) for i in range(len(d)) if d[i] >= value]
    # 
    list_of_predictors.append(u)
    No_of_predictors.append(len(u))
    X_training = X_train[u]
    X_value = X_val[u]
    # 
    
    etc = ExtraTreesClassifier(n_jobs = -1)
    etc.fit(X_training,y_train)
    y_pred = etc.predict(X_value)
    recall = recall_score(y_val,y_pred)
    precision = precision_score(y_val,y_pred)
    roc_auc = roc_auc_score(y_val,y_pred)
    Overall_Accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val,y_pred)
    recall_scores.append(recall)
    precision_scores.append(precision)
    roc_auc_scores.append(roc_auc)
    overall_accuracy_scores.append(Overall_Accuracy)
    f1_scores.append(f1)

# %%
# Plotting the values against
metrics = [precision_scores,recall_scores,roc_auc_scores,f1_scores, overall_accuracy_scores]
metrics_name = ['precision_scores','recall_scores','roc_auc_scores','f1_scores','overall_accuracy_scores']
for k in range(len(metrics)):
    x_val = [str(i) for i in No_of_predictors]
    y_value = metrics[k].copy()
    plt.figure(figsize = (12,5))
    sns.lineplot(x = x_val, y = y_value)
    plt.xlabel("No. of Predictors")
    plt.ylabel(metrics_name[k])
    plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x = roc_auc_scores.index(max(roc_auc_scores))
etrc = ", ".join(list_of_predictors[x])
etrc_score_library = {"ROC AUC Score":round(roc_auc_scores[x],2),"Recall Score":round(recall_scores[x],2),'Precision Score':round(precision_scores[x],2), 'F1 Score':round(f1_scores[x],2), "Overall Accuracy":round(overall_accuracy_scores[x],2),'Optimum predictors':No_of_predictors[x], 'list_of_predictors':etrc}
list_of_models.append('Extra Trees Classifier')
print(etrc_score_library)
# Out:
# {'ROC AUC Score': 0.56, 'Recall Score': 0.26, 'Precision Score': 0.31, 'F1 Score': 0.28, 'Overall Accuracy': 0.75, 'Optimum predictors': 4, 'list_of_predictors': 'id55, TiempoMedioSINCO, AnyoPoliza, Cliente_Diverso'}

# %%
combined_model_library.append(etrc_score_library)

# %% [markdown]
# ## Random Forest Classifier

# %%
# Fitting the Random Forest Classifier Algorithm on the training dataset

rfc = RandomForestClassifier(n_jobs = -1)
rfc.fit(X_train,y_train)

# Predicting the target variable using the trained model

y_pred = lgb.predict(X_val)

# Classification Report

print("The Classification report for LGBM Classifier", end = "\n\n")
print(classification_report(y_val, y_pred))

# Importance of each attribute/features

rfc_results = pd.DataFrame(X_train.columns)
rfc_results.rename(columns = {0:"Feature Names"}, inplace = True)
rfc_results['Feature Importance'] = rfc.feature_importances_
print("----------------------------------------------------")
print("The List of Features and their respective importance", end = "\n")
rfc_results
# Out:
# The Classification report for LGBM Classifier
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90      8372
#            1       0.67      0.19      0.30      1937
#
#     accuracy                           0.83     10309
#    macro avg       0.76      0.59      0.60     10309
# weighted avg       0.81      0.83      0.79     10309
#
# ----------------------------------------------------
# The List of Features and their respective importance
#                        Feature Names  Feature Importance
# 0                               id17            0.005457
# 1                               id18            0.012199
# 2                               id21            0.005343
# 3                               id55            0.041192
# 4                             id58_1            0.003334
# 5                             id58_2            0.006013
# 6                             id58_3            0.002190
# 7                               id59            0.005982
# 8                               id60            0.006163
# 9                               id61            0.006016
# 10                              id70            0.019460
# 11              ValorVehiculoMercado            0.023554
# 12               SINCOTotalVehiculos            0.012944
# 13                           DGT_001            0.004681
# 14                           DGT_002            0.004401
# 15                           DGC_001            0.004400
# 16                           DGC_002            0.004577
# 17                           DGC_003            0.004397
# 18                           DGC_004            0.003315
# 19                           DGC_005            0.004262
# 20                           DGC_006            0.004460
# 21                           DGC_007            0.004539
# 22                           DGC_008            0.005106
# 23                           DGC_009            0.004668
# 24                           DGC_010            0.004635
# 25                           DGC_011            0.005097
# 26                           DGC_012            0.004953
# 27                           DGC_013            0.004349
# 28                           DGC_014            0.004670
# 29                           DGC_015            0.004285
# 30                           DGC_016            0.004753
# 31                           DGC_017            0.005192
# 32                           DGC_018            0.005109
# 33                           DGC_019            0.004756
# 34                           DGC_020            0.004721
# 35                           INE_001            0.004375
# 36                           INE_002            0.004224
# 37                           INE_003            0.003998
# 38                           INE_004            0.004231
# 39                           INE_005            0.004381
# 40                           INE_006            0.004057
# 41                           INE_007            0.004672
# 42                           INE_008            0.004528
# 43                           INE_009            0.004425
# 44                           INE_010            0.004207
# 45                           INE_011            0.004082
# 46                           INE_012            0.004527
# 47                           INE_013            0.003786
# 48                           INE_014            0.003813
# 49                           INE_015            0.003925
# 50                           INE_016            0.004610
# 51                           INE_017            0.003866
# 52                           INE_018            0.004844
# 53                           INE_019            0.004682
# 54                           INE_020            0.004188
# 55                           INE_021            0.004062
# 56                           INE_022            0.003795
# 57                           INE_023            0.004392
# 58                           INE_024            0.004464
# 59                           INE_025            0.003794
# 60                           INE_026            0.003838
# 61                           INE_027            0.004762
# 62                           INE_028            0.003955
# 63                           INE_029            0.003839
# 64                           INE_030            0.004015
# 65                           INE_031            0.004204
# 66                           INE_032            0.004155
# 67                           INE_033            0.004357
# 68                           INE_034            0.004791
# 69                           INE_035            0.004343
# 70                           INE_036            0.004237
# 71                           INE_037            0.004674
# 72                           INE_038            0.004268
# 73                           INE_039            0.004060
# 74                           INE_040            0.004116
# 75                           INE_041            0.004042
# 76                           INE_042            0.004665
# 77                           INE_043            0.004241
# 78                           INE_044            0.004290
# 79                           INE_045            0.004628
# 80                           INE_046            0.004304
# 81                           INE_047            0.004125
# 82                           INE_048            0.004465
# 83                           INE_049            0.004021
# 84                           INE_050            0.003973
# 85                           INE_051            0.004654
# 86                           INE_052            0.003881
# 87                           INE_053            0.004227
# 88                           INE_054            0.003955
# 89                           INE_055            0.004291
# 90                           INE_056            0.004261
# 91                           INE_057            0.004411
# 92                           SEA_001            0.006986
# 93                           SEA_002            0.006873
# 94                           SEA_003            0.006909
# 95                           SEA_004            0.007024
# 96                           SEA_005            0.006795
# 97                           SEA_006            0.006856
# 98                           SEA_007            0.006745
# 99                           SEA_008            0.007410
# 100                          SEA_009            0.007197
# 101                          SEA_010            0.007535
# 102                          OSM_001            0.004703
# 103                          IGN_001            0.004763
# 104                          REP_001            0.004497
# 105                          REP_002            0.004163
# 106                          REP_003            0.004206
# 107                          REP_004            0.004744
# 108                          REP_005            0.004808
# 109                          REP_006            0.004852
# 110                          REP_007            0.004309
# 111                          REP_008            0.004938
# 112                          REP_009            0.004380
# 113                          REP_010            0.004732
# 114                         ScoreAda            0.010463
# 115                   NacionalidadID            0.004254
# 116                      ProvinciaID            0.001715
# 117                    CiaAnteriorID            0.015252
# 118                        ComarcaID            0.002947
# 119                      TiempoSINCO            0.020581
# 120                   PerteneceSINCO            0.009041
# 121             TotalMatriculasSINCO            0.010989
# 122                 TiempoMedioSINCO            0.025011
# 123                TiempoSeguroSINCO            0.019072
# 124                 TiempoSINCO_Anos            0.020777
# 125       FrecuenciaDanyosMateriales            0.010367
# 126       FrecuenciaDanyosPersonales            0.002396
# 127         FrecuenciaSiniestroSINCO            0.010202
# 128                NV_AutomovilSINCO            0.011395
# 129              NV_MotocicletaSINCO            0.005394
# 130                    NV_OtrosSINCO            0.002593
# 131                       ScoreCanal            0.013408
# 132                             Edad            0.020112
# 133                Antiguedad_Carnet            0.019685
# 134                       AnyoPoliza            0.018686
# 135               AntiguedadVehiculo            0.017959
# 136                             id24            0.000459
# 137                             id71            0.007135
# 138           SINCOMatriculaIncluida            0.007669
# 139                    ContrataLunas            0.001815
# 140               ContrataAsistencia            0.000965
# 141            ContrataDanyosPropios            0.002543
# 142                     Conductor2ID            0.003042
# 143      NumeroDanyosMaterialesSINCO            0.004683
# 144     ProcesoDanyosMaterialesSINCO            0.001240
# 145      NumeroDanyosPersonalesSINCO            0.001197
# 146     ProcesoDanyosPersonalesSINCO            0.000670
# 147                           id72_2            0.004247
# 148                         riesgo_0            0.002952
# 149                         riesgo_4            0.000969
# 150                         riesgo_3            0.001652
# 151                         riesgo_2            0.002362
# 152                         riesgo_1            0.000426
# 153                           id13_B            0.001825
# 154                           id13_C            0.002492
# 155                           id13_D            0.002803
# 156                           id13_E            0.003603
# 157                           id13_F            0.002475
# 158                           id13_G            0.001468
# 159                           id13_H            0.002121
# 160                           id13_I            0.000608
# 161                           id13_Z            0.000230
# 162                     id14_EXPANDE            0.001662
# 163                      id14_INICIA            0.000659
# 164               id14_MANTENIMIENTO            0.000448
# 165                      id14_OPTIMA            0.002010
# 166                 id14_OPTIMA_PLUS            0.000402
# 167                    id14_PROYECTA            0.002511
# 168            id15_AGTES_VINCULADOS            0.000905
# 169                  id15_CORREDORES            0.002279
# 170                   id15_EMPLEADOS            0.000216
# 171                id15_OFIC_ENTIDAD            0.000433
# 172              id54_ANUAL_EFECTIVO            0.003605
# 173       id54_SEMESTRAL_DOMICILIADO            0.003733
# 174          id54_SEMESTRAL_EFECTIVO            0.000944
# 175               Subramo_CICLOMOTOR            0.000448
# 176  Subramo_COMERCI_MENOS_DE_3_5TN_            0.002524
# 177              Subramo_MOTOCICLETA            0.000976
# 178  Subramo_TURISMO_NO_CUADRICICLOS            0.002455
# 179      Subramo_VEHICULOS_AGRICOLAS            0.000002
# 180   Subramo_VEHICULOS_INDUSTRIALES            0.000000
# 181        TipoConsultaSINCO_Tomador            0.001236
# 182                        NotaLUA_B            0.000606
# 183                        NotaLUA_C            0.000985
# 184                        NotaLUA_D            0.001857
# 185                        NotaLUA_E            0.002134
# 186                        NotaLUA_F            0.001740
# 187                        NotaLUA_G            0.001021
# 188                            SINCO            0.000000
# 189                  Cliente_Diverso            0.011685

# %%
d = rfc.feature_importances_
r = list(X.columns)
max_imp = max(d)
min_imp = min(d)
val = list(np.linspace(max_imp, min_imp, 50))
f1_scores = []
recall_scores = []
precision_scores = []
roc_auc_scores = []
overall_accuracy_scores = []
list_of_predictors = []
No_of_predictors = []
for value in val:
    u = []
    columns = [u.append(r[i]) for i in range(len(d)) if d[i] >= value]
    # 
    list_of_predictors.append(u)
    No_of_predictors.append(len(u))
    X_training = X_train[u]
    X_value = X_val[u]
    # 
    
    rfc = RandomForestClassifier(n_jobs = -1)
    rfc.fit(X_training,y_train)
    y_pred = rfc.predict(X_value)
    recall = recall_score(y_val,y_pred)
    precision = precision_score(y_val,y_pred)
    roc_auc = roc_auc_score(y_val,y_pred)
    Overall_Accuracy = accuracy_score(y_val, y_pred)
    f1 = f1_score(y_val,y_pred)
    recall_scores.append(recall)
    precision_scores.append(precision)
    roc_auc_scores.append(roc_auc)
    overall_accuracy_scores.append(Overall_Accuracy)
    f1_scores.append(f1)

# %%
# Plotting the values against
metrics = [precision_scores,recall_scores,roc_auc_scores,f1_scores,overall_accuracy_scores]
metrics_name = ['precision_scores','recall_scores','roc_auc_scores','f1_scores','overall_accuracy_scores']
for k in range(len(metrics)):
    x_val = [str(i) for i in No_of_predictors]
    y_value = metrics[k].copy()
    plt.figure(figsize = (12,5))
    sns.lineplot(x = x_val, y = y_value)
    plt.xlabel("No. of Predictors")
    plt.ylabel(metrics_name[k])
    plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x = roc_auc_scores.index(max(roc_auc_scores))
rfc = ", ".join(list_of_predictors[x])
rfc_score_library = {"ROC AUC Score":round(roc_auc_scores[x],2),"Recall Score":round(recall_scores[x],2),'Precision Score':round(precision_scores[x],2), 'F1 Score':round(f1_scores[x],2), "Overall Accuracy":round(overall_accuracy_scores[x],2),'Optimum predictors':No_of_predictors[x], 'list_of_predictors':rfc}
list_of_models.append('Random Forest')
print(rfc_score_library)
# Out:
# {'ROC AUC Score': 0.57, 'Recall Score': 0.16, 'Precision Score': 0.68, 'F1 Score': 0.25, 'Overall Accuracy': 0.83, 'Optimum predictors': 21, 'list_of_predictors': 'id18, id55, id70, ValorVehiculoMercado, SINCOTotalVehiculos, ScoreAda, CiaAnteriorID, TiempoSINCO, TotalMatriculasSINCO, TiempoMedioSINCO, TiempoSeguroSINCO, TiempoSINCO_Anos, FrecuenciaDanyosMateriales, FrecuenciaSiniestroSINCO, NV_AutomovilSINCO, ScoreCanal, Edad, Antiguedad_Carnet, AnyoPoliza, AntiguedadVehiculo, Cliente_Diverso'}

# %%
combined_model_library.append(rfc_score_library)

# %%
df_model_summary = pd.DataFrame(combined_model_library)

# %%
df_model_summary['Model Type'] = list_of_models

# %%
df_model_summary = df_model_summary[['Model Type','ROC AUC Score', 'Recall Score', 'Precision Score', 'F1 Score',
       'Overall Accuracy', 'Optimum predictors', 'list_of_predictors',
       ]]

# %%
df_model_summary
# Out:
#                  Model Type  ROC AUC Score  Recall Score  Precision Score  \
# 0                   XGBoost           0.60          0.24             0.63
# 1      Light Gradient Boost           0.59          0.21             0.66
# 2  Decision Tree Classifier           0.58          0.33             0.30
# 3    Extra Trees Classifier           0.56          0.26             0.31
# 4             Random Forest           0.57          0.16             0.68
#
#    F1 Score  Overall Accuracy  Optimum predictors  \
# 0      0.35              0.83                   9
# 1      0.32              0.83                  12
# 2      0.31              0.73                  17
# 3      0.28              0.75                   4
# 4      0.25              0.83                  21
#
#                                   list_of_predictors
# 0  id55, PerteneceSINCO, FrecuenciaSiniestroSINCO...
# 1  id55, id70, ValorVehiculoMercado, TiempoSINCO,...
# 2  id18, id55, id70, ValorVehiculoMercado, SINCOT...
# 3  id55, TiempoMedioSINCO, AnyoPoliza, Cliente_Di...
# 4  id18, id55, id70, ValorVehiculoMercado, SINCOT...

# %%
df_model_summary.to_csv("df_model_1_summary.csv")

# %%
# Selecting the best model out of all the models

model_used = {'XGBoost':xgb, 'Light Gradient Boost':lgb, 'Decision Tree Classifier':dtc, 'Extra Trees Classifier':etc, 'Random Forest':rfc}
index_no = df_model_summary[df_model_summary['ROC AUC Score'] == df_model_summary['ROC AUC Score'].max()].index[0]
best_model = model_used[df_model_summary[df_model_summary['ROC AUC Score'] == df_model_summary['ROC AUC Score'].max()].loc[index_no,'Model Type']]

# %%
# Selecting the list of predictors for the best model
predictors = df_model_summary.loc[index_no, 'list_of_predictors']
imp_pred_list = predictors.split(", ")

# Selecting the best modelout of all the models

best_model_name = df_model_summary.loc[index_no,"Model Type"]
best_model = model_used[best_model_name]

#imp_pred_list.append('BMA_pol_auto')

print("The model that performs best is:",df_model_summary.loc[index_no,"Model Type"] )
print("The optimum predictors for this model are:\n")
for i in range(len(imp_pred_list)):
    print(i+1,".",imp_pred_list[i], end = '\n')
# Out:
# The model that performs best is: XGBoost
# The optimum predictors for this model are:
#
# 1 . id55
# 2 . PerteneceSINCO
# 3 . FrecuenciaSiniestroSINCO
# 4 . AnyoPoliza
# 5 . ContrataLunas
# 6 . NumeroDanyosMaterialesSINCO
# 7 . id13_H
# 8 . id14_MANTENIMIENTO
# 9 . Cliente_Diverso

# %%
# Preparation of the Final dataset

df_final = X_test.copy()
df_final['Actual Classification'] = y_test

# Dropping the target column 'BMA_pol_auto' from the test dataset for prediction
X_test = X_test.drop('BMA_pol_auto', axis = 1)
y_pred_best = best_model.predict(X_test)

# Incorporating the predicted values into the Final dataset
df_final['Predicted_profitability'] =  y_pred_best
df_final.reset_index(drop = True, inplace = True)

# %%
print("The ROC_AUC Score for the predicted dataset is:", round(roc_auc_score(y_test,y_pred_best),2))
print(confusion_matrix(y_test,y_pred_best))
# Out:
# The ROC_AUC Score for the predicted dataset is: 0.59
# [[8029  299]
#  [1539  443]]

# %%
df_final['Predicted BMA'] = [df_final.loc[i,'BMA_pol_auto'] if df_final.loc[i,'Predicted_profitability'] == 0 else 0 for i in range(df_final.shape[0]) ]

# %%
df_final.to_csv("Model_1.csv")

# %%
# Total number of people offered policy before ML model implementation

original_count = df_final.shape[0]
print("Total number of people who were provided insurance before model implementation: ",original_count)

# Total number of people offered policy after ML model implementation

Final_count = df_final.shape[0] - df_final['Predicted_profitability'].sum()
print("Total number of people who were provided insurance after model implementation: ",Final_count)

# Percentage increment  
print("Percentage of people rejected: ",round(((original_count-Final_count)/original_count)*100,2),"%")
# Out:
# Total number of people who were provided insurance before model implementation:  10310
# Total number of people who were provided insurance after model implementation:  9568
# Percentage of people rejected:  7.2 %

# %%
# Total Revenue Calculation

Original_revenue = round(df_final['BMA_pol_auto'].sum(),0)
Final_revenue = round(df_final['Predicted BMA'].sum(),0)

# Revenue Calculation per person

Initial = round(Original_revenue/original_count,2)
Final = round(Final_revenue/Final_count,2)

# Final Results 

print("The total revenue before application of ML Model is: ",Original_revenue)
print("The total revenue after application of ML Model is: ", Final_revenue)
print("Revenue per customer before application of ML is: ", round(Original_revenue/original_count,2))
print("Revenue per customer after application of ML is: ", round(Final_revenue/Final_count,2))
print(f"Revenue per customer increased by {round(Final/Initial,2)} times after application of ML model")
# Out:
# The total revenue before application of ML Model is:  573891.0
# The total revenue after application of ML Model is:  1026303.0
# Revenue per customer before application of ML is:  55.66
# Revenue per customer after application of ML is:  107.26
# Revenue per customer increased by 1.93 times after application of ML model

# %%
print(classification_report(y_test,y_pred_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90      8328
#            1       0.60      0.22      0.33      1982
#
#     accuracy                           0.82     10310
#    macro avg       0.72      0.59      0.61     10310
# weighted avg       0.79      0.82      0.79     10310
